# %%
#-*- encoding:utf-8
from tika import parser

PDFfileName = input()
# Out:
# 초급어휘목록개발.pdf

# %%
print("텍스트 파일은 다음 폴더에 저장됩니다.")

print("D:\data_han")
inputpath = PDFfileName
parsed = parser.from_file(PDFfileName)
content=parsed['content']
print(content.strip())
#print(parsed["content"])
fileOut = open('fileOut.txt', 'w', encoding='utf-8')



print(parsed['content'], file=fileOut)
fileOut.close()
# Out:
# 텍스트 파일은 다음 폴더에 저장됩니다.
# D:\data_han
# 2020-09-19 19:41:58,254 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2020-09-19 19:42:03,275 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 초급어휘목록개발.hwp
#
#
# 연구보고 CRE 20092-2
#
# 한국어능력시험 초급 어휘 목록 개발 연구
#
# 연구책임자 김 중 섭
#
#
#
# 한국어능력시험 초급 어휘 목록 개발 연구
#
# [연구책임자]
#
# 김중섭 (경희대국어국문학과)
#
# [공동연구원]
#
# 김정숙 (고려대국어국문학과)
#
# 이해영 (이화여대한국학과)
#
# 이정희 (경희대국제교육원)
#
# 김일환 (고려대민족문화연구원)
#
# 최민우 (고려대민족문화연구원)
#
# [연구보조원]
#
# 고우리 (경희대국제교육원)
#
# 김선주 (경희대국제교육원)
#
# 장미정 (고려대국어국문학과석사과정)
#
# 정미경 (고려대국어국문학과석사과정)
#
# 이 경 (고려대국어국문학과석사과정)
#
#
#
#
#
# 차 례
#
# Ⅰ. 서론 ·······························································································································1
#
# Ⅱ. 분석 자료 및 처리 과정 ······························································································2
#
# 1. 분석 자료 유형 및 규모 ···························································································2
#
# 가. 한국어 교육용 교재 ····························································································3
#
# 나. 한국어능력시험 ····································································································3
#
# 다. 세종구어말뭉치 ·····································································································4
#
# 2. 분석 자료 처리 과정 ································································································5
#
# 가. 텍스트 입력 ·········································································································6
#
# 나. 형태소 분석 및 주석 ···························································································7
#
# 다. 오류 수정 ··············································································································9
#
# 라. 통계 추출 ··············································································································9
#
# 마. 통계 결과 후처리 ································································································9
#
# Ⅲ. 자료 분석 결과 ·········································································································11
#
# 1. 표준 어휘 선정 및 목록 ·························································································11
#
# 가. 표준 어휘 선정 과정 ···························································································11
#
# 나. 표준 어휘 선정 대상 목록 ················································································12
#
# 다. 표준 어휘 선정 목록 ·························································································85
#
# 2. 표준 문법 항목 선정 및 목록 ··············································································127
#
# 가. 표준 문법 항목 선정 과정 ··············································································127
#
# 나. 문법 항목 선정 대상 목록 ··············································································128
#
# 다. 표준 문법 항목 선정 목록 ··············································································135
#
#
#
# - 4 -
#
# 참고문헌 ··························································································································136
#
# 표차례
#
# <표Ⅱ-1> 한국어능력시험 평가 영역 및 문항 ··································································4
#
# <표Ⅱ-2> 분석 자료 규모 ··································································································5
#
# <표Ⅱ-3> 형태 분석에 사용된 기호 ··················································································8
#
# <표Ⅲ-1> 형태소 분석 전후 문법 항목 비교 ································································128
#
# <표Ⅲ-2> 선정된 문법 항목 ···························································································135
#
#
#
# - 1 -
#
# Ⅰ. 서론
#
# 이 연구는 한국어능력시험 문항 개발에서 활용할 ‘초급 표준 어휘 목록’ 선정을 목
#
# 적으로 한다. 이 연구에서 선정․제시하는 표준 어휘는 한국어능력시험 및 한국어 교
#
# 재 개발 나아가 한국어 교육의 표준적인 교육 내용을 제시하는 데에 도움이 될 것이
#
# 다.
#
# 한류의 확산과 이주 노농자, 결혼이민자 계층의 증가로 인해 한국어 교육에 대한 수
#
# 요가 급증하고 있으며, 그들을 위한 한국어 교육과정이 다양화 되고 있으며 이와 함께
#
# 개발되는 교재들도 다양해지고 있다. 그러나 교육 기관마다 기준과 범위를 달리하는
#
# 어휘 및 문법 목록의 선정으로 학습자의 학습 부담뿐만 아니라 평가에 대한 부담까지
#
# 안게 되어 학습자는 이중의 부담을 안고 한국어를 학습하게 된다. 평가는 학습한 내
#
# 용이 평가 도구에 내용적 요소로 반영될 때 타당성을 가질 수 있다. 그러기 위해서는
#
# 현행 한국어능력시험의 기출 어휘를 분석하여 체계적인 어휘 목록을 작성할 필요가
#
# 있다. 이러한 어휘 목록의 작성으로 인해 학습자가 평가에 대해 대비할 수 있을 뿐만
#
# 아니라 교육 현장의 교육용 어휘 목록으로 확정될 수도 있을 것이다.
#
# 한국어능력시험(TOPIK, Test of Proficiency in Korean)은 국내․외의 다양한 목적을
#
# 가진 한국어 학습자가 자신의 학습 결과를 확인하고 한국어 능력을 객관적으로 평가
#
# 할 수 있는 표준적인 평가 도구이다. 따라서 한국어능력시험이 타당성과 객관성을 확
#
# 보하기 위해서는 문항의 적절성과 함께 각 영역에서 활용되는 어휘의 객관성 확보도
#
# 필요하다. 표준 어휘 목록은 향후 한국어능력시험 문항 개발에 활용되어 평가의 타당
#
# 성 및 객관성을 확보할 수 있으며, 표준 어휘 목록의 제공으로 학습자의 학습 및 평가
#
# 에 대한 부담을 최소화할 수 있을 것이다. 나아가 한국어교육의 표준적인 교육 과정
#
# 및 교수요목 설계의 기초로서의 역할을 할 것이다.
#
# 이에 이 연구에서는 먼저 한국어능력시험 초․중․고급 단계 중 초급 문항의 어휘
#
# 를 분석하고, 이와 함께 (정규) 교육 기관의 한국어교재, 어휘 출현 양상과 빈도수를
#
# 확인할 수 있는 세종구어말뭉치를 분석하여 한국어능력시험 초급 표준 어휘 목록을
#
# 선정․제시한다.
#
#
#
# - 2 -
#
# Ⅱ. 분석 자료 및 처리 과정
#
# 어휘는 그 범위가 넓으며 사용 양상 또한 다양하며 문법의 기술 및 설명, 읽기, 듣기
#
# 의 기초가 되는 것이 어휘이다. 그러므로 어휘는 언어 학습에서 가장 기본적인 역할을
#
# 하는 것이다. 현재까지 한국어교육에서 이루어진 어휘 연구는 한국어교육용 기초 어휘,
#
# 기본 어휘에 대한 개념 정의와 그 어휘들의 범위 설정에 대한 것이 주를 이루었다. 그
#
# 러나 앞서 살핀 바, 한국어교육의 표준적인 교육 틀을 마련하고 평가의 타당성을 확보
#
# 하기 위해서는 초급 평가 목적에 적절한 어휘를 선정하는 과정이 필수적이라고 할 수
#
# 있다.
#
# 이 연구에서는 현재 출판된 수십 종의 교재 중에서 대학기관의 한국어 교재 목록을
#
# 중심으로 하되, 문어 중심의 교재나 문법 중심 교재는 배제하고 의사소통 중심의 교재
#
# 를 대상으로 선정하였다. 이러한 기준을 통해 5개 한국어 교육 기관에서 출판된 12권
#
# 의 교재를 어휘 선정을 위한 교재로 택하였다.
#
# 또한 좀 더 객관적인 어휘 목록 선정을 위해 제6회 한국어능력시험(TOPIK)부터 14
#
# 회까지 총 9회에 걸친 초급 단계의 어휘․문법, 쓰기, 듣기(듣기 대본 포함), 읽기 시험
#
# 문항의 빈도를 함께 분석하였다. 그리고 현재까지 한국어교육용 어휘 자료로 활용되고
#
# 있는 조남호(2003)의 C등급을 제외한 A등급 어휘 982개와 B등급 어휘 2,111개를 함께
#
# 넣어 분석하였다. 어휘 선정의 전 과정에서 세종구어말뭉치에서 분석된 어휘 빈도를
#
# 참조하였다.
#
# 분석 자료의 처리는 세종구어말뭉치와는 별도로 교재와 한국어능력시험 문항은 연
#
# 구원들이 각 자료의 텍스트를 전산 입력한 후 형태소 분석 및 주석을 달아 통계를 추
#
# 출하여 표준 어휘 목록을 선정하였다.
#
# 1. 분석 자료 유형 및 규모
#
# 위에서 살폈듯이 한국어능력시험의 타당성을 확보하기 위해서는 다양한 텍스트들로
#
# 부터 실제 사용되는 언어의 양상을 파악하고 이를 반영할 필요가 있다. 이를 위해 이
#
# 연구에서는 <한국어 교육용 교재> 5종 12권, 한국어능력시험 6회에서 14회까지 총 9
#
# 종, 4개 영역의 텍스트를 분석하였다. 이와 함께 일상생활에서의 어휘 사용 양상과 빈
#
#
#
# - 3 -
#
# 도 파악을 위해 세종구어말뭉치를 분석하였다.
#
# 분석 자료의 규모는 한국어교육용 교재에서 143,660 어절, 한국어능력시험 51,861 어
#
# 절, 세종구어말뭉치 45,274 어절로 총 240, 795 어절을 추출하였다.
#
# 가. 한국어 교육용 교재
#
# 한국어 학습에 대한 수요가 급증하고 이에 따라 학습자의 요구가 다양해지면서 교
#
# 재의 수도 증가하고 있다. 다양한 교재가 개발되고 종수도 많아지는 것은 한국어교육
#
# 의 발전 과정이라고 할 수 있다. 그러나 교재가 다양해질수록 학습자가 느끼는 학습
#
# 부담감은 커질 것이다. 왜냐하면 어휘란 문법과 같이 한정적이지 않으며 날마다 학습
#
# 하거나 습득해야 하는 어휘가 추가되고 있기 때문이다.
#
# 이 연구에서는 수십 종의 교재 중에서 대학기관의 한국어 교재 목록을 중심으로 하
#
# 되, 문어 중심의 교재나 문법 중심 교재는 배제하고 의사소통 중심의 교재를 대상으로
#
# 선정하였다. 이러한 기준을 통해 5개 한국어 교육 기관에서 출판된 12권의 교재를 어
#
# 휘 선정을 위한 교재로 택하였다.
#
# -『재미있는 한국어 1, 2』(고려대학교, 2000)
#
# -『한국어 1, 2』( 경희대학교, 2003)
#
# -『한국어 1-1, 1-2, 2-1, 2-2』( 연세대학교, 2007)
#
# -『서강 한국어 1, 2』(서강대학교, 2005)
#
# -『이화여자대학교 말이 트이는 한국어 1, 2』(이화여자대학교,1999)
#
# 나. 한국어능력시험
#
# 평가(Test)는 학습한 내용이 평가 도구에 반영될 때 타당성을 가질 수 있다. 그러므
#
# 로 교육 과정과 교육 내용, 교수요목의 표준화는 평가 도구 작성에 중요한 기준이 될
#
# 있다. 그러나 앞서 밝혔듯이 다양한 요구에 의해 수립된 한국어 교육의 교육 과정, 교
#
# 수요목을 표준화하기에는 무리가 따른다. 체계적이고 효율적인 교수요목을 마련하기
#
# 위해서는 먼저 표준화된 평가 도구인 한국어능력시험의 표준화 방안 마련이 필요하다.
#
#
#
# - 4 -
#
# 언어를 구성하는 가장 기본적인 단위를 어휘라고 본다면 한국어능력시험의 각 영역
#
# 을 구성하게 되는 기본 단위도 어휘로 볼 수 있다. 그러므로 한국어능력시험의 표준화
#
# 는 표준 어휘를 마련하는 것과 같다고 할 수 있다.
#
# 한국어능력시험(TOPIK, Test of Proficiency in Korean)은 1997년부터 시행되어 2009
#
# 년 2월 현재 총 14회의 시험이 실시되었다. 이 연구에서는 1회부터 5회까지의 기출 문
#
# 항은 비교적 초기에 시행되었고 그 결과 문항의 질과 내용, 응시자의 합격률, 난이도와
#
# 변별력 등 여러 면에서 안정된 수준을 보이지 못해 제외하였다. 그러한 이유로 6회부
#
# 터 14회까지 치러진 문항을 중심으로 분석하였으며, 6회부터 11회까지는 총 6등급 체
#
# 계로 나뉘어 있어 1급과 2급에서 추출하고, 12회부터 14회까지는 초, 중, 고급 중 초급
#
# 을 해당 어휘로 선정하였다.
#
# 한국어능력시험 시험 구성은 어휘․문법, 듣기, 읽기, 쓰기 영역으로 나뉘어져 있다.
#
# 이 연구에서는 4개 영역 전 문항뿐만 아니라 듣기 지문에서 제시된 대본까지 입력하여
#
# 어휘를 분석 추출하였다.
#
# 한국어능력시험의 평가 영역 및 문항 구성을 표로 보이면 다음과 같다.
#
# <표Ⅱ-1> 한국어능력시험 평가 영역 및 문항
#
# 영 역 어휘-문법 쓰기 듣기 읽기
#
# 4개 영역
#
# 유 형 객관식 단답형 작문형 객관식 객관식 객관식
#
# 문항수 30 4~6 1 10 30 30
#
# 총 400점
#
# 배 점 100 30 30 40 100 100
#
# 다. 세종구어말뭉치
#
# 한국어능력시험에서 추출된 어휘와 한국어 교육용 교재에서 추출된 어휘는 실생활
#
# 에서의 사용 양상이나 빈도수 확인이 어렵기 때문에 이 연구에서는 국립국어원 <21세
#
# 세종계획>에서 구축한 말뭉치 자료를 함께 분석하였다.
#
# <21세기 세종계획>은 국어 정보화를 목적으로 1998년부터 2007년까지 10년 동안 구
#
# 축되었으며 형태 분석 말뭉치 총 576개 파일, 약 15,200,000 어절 규모이다.1)
#
#
#
# - 5 -
#
# 이 연구에서는 <21세기 세종계획> 중 구어 및 준구어 말뭉치를 분석하였다.
#
# 이 연구에서 분석 대상으로 삼은 한국어교육용 교재, 한국어능력시험, 세종구어말뭉
#
# 치의 규모를 정리하면 다음과 같다.
#
# <표Ⅱ-2> 분석 자료 규모
#
# 분석 자료 수량(어절수)
#
# 한국어 교재2)
#
# 고려대 1, 2권3) 62,052
#
# 경희대 초급 1, 2권 24,380
#
# 이화여대 1, 2권 21,585
#
# 서강대 1, 2권 9,764
#
# 연세대 1-1, 1-2, 2-1, 2-2권 25,879
#
# 세종구어말뭉치 45,274
#
# 한국어능력시험(6-14회) 51,861
#
# 계 240,795
#
# 2. 분석 자료 처리 과정
#
# 한국어교육용 교재와 한국어능력시험의 텍스트는 전산 입력도 되어 있지 않은 데다
#
# 형태소 분석 등의 처리도 거치지 않았기 때문에 이들을 세종구어말뭉치와는 별도로
#
# 가공할 필요가 있다. 그 과정을 대략 도식화해 보면 다음과 같다.
#
# 1) 최민우․강범모(2008)
#
# 2) 이후 보고서에는 경희대는 K1, 이화여대 E, 서강대 S, 연세대 Y, 고려대 K2'로 명기한다.
#
# 3) 고려대 교재에는 영어 대역문이 포함되어 있어, 수량 계산에서는 이를 제외하였다.
#
#
#
# - 6 -
#
# <그림Ⅱ-1> 분석 자료 처리 과정
#
# 가. 텍스트 입력
#
# 한국어교육용 교재와 한국어능력시험의 텍스트 입력은 <한글 2007>을 이용하여 해
#
# 당 자료를 연구원이 나누어 입력하였다. 입력 과정에서 어휘 사용 양상과 관계없는 지
#
# 시문이나 기호 등은 삭제하였고, 예비편(또는 한글편)이 수록되어 있는 경우 또한 전산
#
# 입력에 포함시켰다.
#
# 입력 방법은 어절 및 어휘 단위로 나누어 <한글 2007> 프로그램 문서의 한 줄에 한
#
# 단위씩 입력하였다. 자료 입력 과정에서 자료 분석 및 입력에 대한 연구원들의 의견이
#
# 분분하여 조정 과정을 거쳐 다음과 같은 자료 분석 기준을 마련하였다.
#
# ① 단원명에 출현한 어휘는 입력하지 않는다.
#
# ② 지시문은 입력하지 않는다.
#
# ③ 중복 횟수와 관계없이 모두 입력한다.
#
# ④ 삽화나 표에 제시된 어휘는 입력한다.
#
# ⑤ 문법 설명 부분이 있는 경우 예문으로 제시된 문장의 어휘를 입력한다.
#
# ⑥ 어휘가 문장 단위의 문제로 제시되어 있는 완성된 문장을 입력하고 제시 어휘수
#
# 가 많을 경우는 어휘 단위로 입력한다.
#
# 예1) <보기> 바쁘다, 기쁘다
#
# 민수는 지만 친구를 만나 .
#
# 입력: 민수는 바쁘지만 친구를 만나 기뻤습니다.
#
# 예2) <보기> 바쁘다, 기쁘다, 슬프다
#
# 오늘 민수는 .
#
# 입력: 바쁘다
#
# 기쁘다
#
#
#
# - 7 -
#
# 슬프다
#
# 오늘
#
# ⑦ ‘문화’ 영역이 따로 제시되어 있는 경우 ‘문화’ 영역은 입력하지 않는다.
#
# ⑧ 인명(예: 빌리, 민수 따위)은 입력하지 않는다.
#
# ⑨ 문장 단위 대체 연습에서 출현한 어휘는 중복 처리하지 않는다.
#
# ⑩ 숫자, 기호, 단위 등은 입력하되 무의미한 반복의 경우 입력하지 않는다.
#
# ⑪ 발화 순서를 표현하는 어휘는 입력하지 않는다.
#
# ⑫ 번역이 있는 특수 어휘는 입력하지 않는다.
#
# 나. 형태소 분석 및 주석
#
# 입력된 텍스트는 <21세기 세종계획>에서 개발한 자동 형태소 분석 및 주석 도구인
#
# ‘KOMA(Korean Morpheme Analyzer)’ 태거(tagger)를 이용하여 자동 태깅을 하였다.
#
# KOMA에서는 형태 단위로 세분하여 분석 결과를 보여주는데, 이때 사용된 기호를 보
#
# 이면 다음과 같다.
#
#
#
# - 8 -
#
# <표Ⅱ-3> 형태 분석에 사용된 기호
#
# 대분류 소분류 세분류
#
# (1) 체언
#
# 명사NN
#
# 일반명사NNG
#
# 고유명사NNP
#
# 의존명사NNB
#
# 대명사NP
#
# 수사NR
#
# (2) 용언
#
# 동사VV
#
# 형용사VA
#
# 보조용언VX
#
# 지정사VC
# 긍정지정사VCP
#
# 부정지정사VCN
#
# (3) 수식언
#
# 관형사MM
#
# 부사MA
# 일반부사MAG
#
# 접속부사MAJ
#
# (4) 독립언 감탄사IC
#
# (5) 관계언
#
# 격조사JK
#
# 주격조사JKS
#
# 보격조사JKC
#
# 관형격조사JKG
#
# 목적격조사JKO
#
# 부사격조사JKB
#
# 호격조사JKV
#
# 인용격조사JKQ
#
# 보조사JX
#
# 접속조사JC
#
# (6) 의존형태
#
# 어미E
#
# 선어말어미EP
#
# 종결어미EF
#
# 연결어미EC
#
# 명사형전성어미ETN
#
# 관형형전성어미ETM
#
# 접두사XP 체언접두사XPN
#
# 접미사 XS
#
# 명사파생접미사XSN
#
# 동사파생접미사XSV
#
# 형용사파생접미사XSA
#
# 어기XR
#
# (7) 기호
#
# 마침표,물음표, 느낌표 SF
#
# 쉼표, 가운뎃점, 콜론, 빗금 SP
#
# 따옴표, 괄호표, 줄표 SS
#
# 줄임표 SE
#
# 붙임표(물결, 숨김, 빠짐) SO
#
# 외국어 SL
#
# 한자 SH
#
# 기타 기호(논리 수학기호, 화폐기호 등) SW
#
# 명사추정범주 NF
#
# 용언추정범주 NV
#
# 숫자 SN
#
# 분석불능범주 NA
#
#
#
# - 9 -
#
# 다. 오류 수정
#
# <21세기 세종계획>의 자동 형태소 분석기인 KOMA 태거는 분석 성공률이 95%를
#
# 상회하는 것으로 보고되어 있다. 대상 텍스트가 한국어 교육을 위해 집필된 교재라는
#
# 점을 고려하면 KOMA 태거의 분석 정확도는 더욱 높게 나올 것으로 기대할 수 있다.
#
# 그러나 한국어 교재의 특성상 비정규적인 어절 유형이 등장하는 경우가 있어 이들의
#
# 분석 결과를 수정할 필요가 있었다. 예컨대 ‘-(으)세요’와 같은 어절은 자동적으로 올바
#
# 른 분석을 해내기 어렵기 때문에 이들 분석을 수정해 주어야 한다.
#
# 라. 통계 추출
#
# 5종의 한국어 교재와 한국어능력시험의 텍스트들의 형태 분석을 한 후 이들의 통계
#
# 결과를 산출하였다. 품사별 통계를 위해서 “ExtractStat”라는 도구를 자체적으로 개발
#
# 하여 자동으로 품사별 통계 결과를 획득하였다. 세종구어말뭉치의 경우에는 형태 분석
#
# 이 이미 되어 있으므로 통계만 추출하였다.
#
# 마. 통계 결과 후처리
#
# 텍스트를 처리한 결과로 획득한 통계 결과 가운데 초급 어휘를 선별하기 위해서는
#
# 별도의 후처리 작업이 수행될 필요가 있다. 먼저 5개 한국어교육용 교재 가운데 2개
#
# 이상의 교재에서 1회 이상 중복 출현한 형태 목록을 추출하였다(총 3,361개). 그리고
#
# 그 결과를 세종구어말뭉치와 한국어능력시험의 형태 통계 결과와 비교할 수 있도록
#
# 어휘를 정렬하였다. 해당 목록 중에서 부호, 숫자, 로마자, 이형태를 처리한 후 추출한
#
# 항목은 최종 2,633개이다.
#
# 이 과정 가운데 한국어 교재의 통계 결과를 후처리하는 과정을 좀 더 자세히 보이
#
# 면 다음과 같다.
#
# ① 형태 분석된 각 교재의 텍스트로부터 형태소별 통계를 추출한다. 이 결과는 빈도
#
# 순 또는 가나다순으로 정렬하여 작업자가 원하는 형태로 참조하도록 할 수 있다.
#
# ② ①의 5가지 결과물을 모두 비교하여 동일한 형태소가 2개 이상의 교재에서 나타
#
#
#
# - 10 -
#
# 난 경우, 이를 표시하고 그 빈도를 보여주는 표를 구성하였다.
#
# ③ 완성된 결과물은 빈도순으로 정렬하여 텍스트에서 많이 나타난 형태를 쉽게 파
#
# 악할 수 있도록 했다.
#
# 이상의 과정은 수작업만으로 처리하기에는 효율성이 떨어지기 때문에 자체적으로
#
# 분석 도구를 제작하여 활용했다. 도구 제작을 위해 프로그래밍 언어인 '파이썬
#
# '(phython) 버전 2.6을 사용하였다. 파이썬은 초보자부터 전문가까지 폭넓은 사용자층
#
# 을 보유하고 있는 동적 타이핑(dynamic typing) 범용 프로그래밍 언어로써, 다양한 플
#
# 랫폼에서 쓸 수 있고, 라이브러리(모듈)가 풍부하여 대학을 비롯한 여러 교육 기관, 연
#
# 구 기관 및 산업계에서 많이 사용하고 있으며, 다양한 언어의 문자 처리에 매우 강점
#
# 을 지니고 있어 이 연구 과제와 같은 다량의 텍스트 자료 처리에 매우 적합하다.
#
#
#
# - 11 -
#
# Ⅲ. 자료 분석 결과
#
# 1. 표준 어휘 선정 및 목록
#
# 가. 표준 어휘 선정 과정
#
# 표준 어휘 선정 과정은 총 5차에 걸쳐 진행되었으며, 1차에서는 한국어교육용 교재
#
# 와 한국어능력시험에서 2회 이상 출현한 어휘, 2차에서는 1차에서 추출한 어휘와 조남
#
# 호(2003)에서 제시한 어휘와 비교․검토하여 두 개의 자료에서 공통으로 출현한 어휘,
#
# 3차에서는 2차에서 추출된 어휘를 한국어능력시험과 세종구어말뭉치를 참조하여 재추
#
# 출하였으며, 이 과정에서는 연구자의 교육 경험과 모어 화자로서의 직관을 통해 판정
#
# 하였다. 4차 어휘 선정 과정에서는 1차에서 1회 출현한 어휘, 즉 1차 추출 과정에서 선
#
# 정되지 않은 어휘와 조남호(2003), 한국어능력시험을 다시 비교․검토하여 공통으로 출
#
# 현한 어휘를 추출하였다. 5차 선정 과정에서는 3, 4차에서 추출된 어휘를 어휘장, 문법
#
# 형태 연습에서 제시할 수 있는 어휘, 연구자의 교육 경험 즉, 한국어 교육에서 적합하
#
# 다고 생각되는 어휘들을 중심으로 최종 1,560개를 추출하였다.
#
# 먼저, 1차 분석에서는 한국어교육용 교재와 한국어능력시험에서 2회 이상 출현한 어
#
# 휘 3,361개를 추출하였다. 이 과정에서 한국어교육용 교재, 한국어능력시험에서 1회만
#
# 출현한 어휘들은 어휘 빈도 산출에서 제외하였다.
#
# 둘째, 2차 분석에서는 1차에서 추출한 3,361개의 어휘를 조남호(2003)의 A, B 어휘
#
# 목록과 비교․검토하여 두 항목에서 공통으로 출현한 어휘 1,713개를 추출하였다.
#
# 셋째, 3차 분석에서는 2차에서 추출된 어휘 1,713개를 한국어능력시험과 세종구어말
#
# 뭉치를 참조하여 재추출하였다. 3차 과정에서 비교 대상이 된 세종구어말뭉치는 ‘교육’
#
# 이라는 특수성을 고려하여 참조만 하였고 주 비교 대상으로 삼은 것은 한국어능력시
#
# 험이다. 3차 분석을 통해 1,402개의 어휘를 추출하였다.
#
# 넷째, 4차 분석에서는 1차에서 제외되었던 500개의 어휘와 한국어능력시험, 조남호
#
# (2003)을 고려하여 63개의 어휘를 선택하여 1,465항목을 추출하였다.
#
# 다섯째, 5차 분석에는 4차 분석까지 추출한 1,465개의 어휘를 한국어교육용 교재 빈
#
# 도, 한국어능력시험 출현 빈도, 세종구어말뭉치, 어휘장, 어휘 제시의 체계성 및 외국인
#
#
#
# - 12 -
#
# 을 대상으로 한 한국어 초급 어휘 목록임을 고려하여 최종 1,560개를 추출하였다.
#
# 예를 들어, 조남호(2003)에서는 ‘한식, 중식, 일식’과 같은 어휘는 ‘C'로 설정되어 있
#
# 지만 한국어교육에서는 ’주문하기‘와 같은 기능교수요목에서는 중요한 위치를 차지하
#
# 기 때문에 포함시켰다.
#
# 나. 표준 어휘 선정 대상 목록
#
# 이와 같은 과정을 거쳐 선정된 표준 어휘를 선정 과정별로 보이면 다음과 같다.
#
# (1) 한국어교육용 교재 2회 이상 출현 항목(1차 2,633개)
#
# 형태 품사 K1 E S Y K2 합계 TOPIK 세종구어4)
#
# ===============================================================================
#
# 가게 NNG 40 11 3 37 40 131 70 35
#
# 가격 NNG 1 7 3 2 27 40 2 61
#
# 가구 NNG X 7 X 2 16 25 9 18
#
# 가로 NNG 1 2 X X X 3 X 4
#
# 가루 NNG X 1 X 1 2 4 X 8
#
# 가방 NNG 26 30 11 44 2 113 67 64
#
# 가수 NNG 8 4 X 15 1 28 2 15
#
# 가스 NNG 1 X X 4 X 5 X X
#
# 가스레인지NNG X X X 1 1 2 X X
#
# 가슴 NNG X 2 X X 2 4 X 53
#
# 가역 NNG X 1 X X 3 4 X X
#
# 가요 NNG 5 1 4 1 7 18 60 14
#
# 가운데 NNG X 4 X 1 7 12 2 109
#
# 가을 NNG 6 4 8 12 15 45 28 24
#
# 가입 NNG X X X 1 3 4 X 26
#
# 가전제품 NNG X 1 X 2 X 3 X X
#
# 가족 NNG 20 25 10 53 73 181 68 98
#
# 가족사진 NNG 1 X X X 5 6 X X
#
# 가죽 NNG X 4 X 2 X 6 1 8
#
# 4) 세종구어 빈도 자료에 ‘NONE’ 항목이 많이 나타난 것은 주로 대상 자료를 순구어 위주로 선택한 점과
#
# 대부분 즉흥적 독백이나 강연 텍스트가 많이 포함되어 있기 때문이며, 몇 번의 확인 과정을 통해 통계
#
# 상의 오류가 아닌 것은 확인하였다.
#
#
#
# - 13 -
#
# 가지 NNG X 1 X 1 1 3 X 12
#
# 간 NNG 2 1 1 1 1 6 1 20
#
# 간식 NNG 1 1 5 X X 7 X 3
#
# 간장 NNG X 1 10 5 1 17 X 17
#
# 간호사 NNG 3 1 X 6 X 10 1 9
#
# 갈비 NNG 3 2 4 8 1 18 X 3
#
# 갈비찜 NNG X 3 X 5 X 8 X X
#
# 갈비탕 NNG 1 X 2 6 10 19 X 1
#
# 갈색 NNG 1 3 1 X 20 25 1 8
#
# 감 NNG X 1 X 2 1 4 X 29
#
# 감기 NNG 16 5 5 9 27 62 13 66
#
# 감기약 NNG 2 X X 2 4 8 1 6
#
# 감독 NNG X 1 X 1 X 2 X 82
#
# 감동 NNG X X X 2 3 5 X 47
#
# 감사 NNG 5 28 12 7 24 76 27 112
#
# 감상 NNG 2 1 X 3 1 7 X 29
#
# 감자 NNG X 3 1 3 X 7 X 11
#
# 값 NNG 11 5 1 24 7 48 14 96
#
# 강 NNG 10 16 6 9 17 58 3 28
#
# 강사 NNG X X X 1 1 2 X 41
#
# 강아지 NNG 4 2 1 2 X 9 4 13
#
# 개 NNG 3 1 1 2 3 10 6 47
#
# 개나리 NNG X 1 X 2 X 3 X 1
#
# 개인 NNG X 1 X 1 11 13 X 5
#
# 거리 NNG 4 2 X 10 13 29 4 90
#
# 거실 NNG 7 7 10 2 3 29 3 3
#
# 거울 NNG 4 2 X 3 5 14 3 8
#
# 거짓말 NNG 1 1 1 2 5 10 X 44
#
# 걱정 NNG X 18 9 10 46 83 15 120
#
# 건 NNG 24 14 X 38 1 77 68 1
#
# 건강 NNG 10 16 6 12 17 61 40 56
#
# 건너편 NNG 2 2 4 2 9 19 3 6
#
# 건물 NNG 4 X X 7 1 12 15 75
#
# 검사 NNG X 1 X 1 X 2 X 97
#
# 검색 NNG 1 1 X 2 X 4 X 30
#
# 검은색 NNG 1 1 X 4 X 6 1 15
#
# 게 NNG 40 11 3 37 2 93 70 35
#
#
#
# - 14 -
#
# 게시판 NNG 7 2 3 X 6 18 X 15
#
# 게임 NNG 6 X 5 4 12 27 2 35
#
# 겨울 NNG 19 11 8 33 33 104 19 67
#
# 결과 NNG X 2 X X 3 5 X 156
#
# 결석 NNG 1 2 X 1 X 4 1 2
#
# 결심 NNG X 2 X X 1 3 X 6
#
# 결정 NNG X 4 X 6 6 16 1 118
#
# 결혼 NNG 5 18 4 15 11 53 14 293
#
# 결혼식 NNG 1 9 X 18 10 38 2 53
#
# 결혼식장 NNG 1 X X 1 X 2 1 2
#
# 겸손 NNG X 1 X X 1 2 X 4
#
# 경 NNG 11 11 7 29 3 61 31 2
#
# 경기 NNG X 4 11 1 2 18 X 148
#
# 경기장 NNG X X X 5 5 10 1 7
#
# 경비 NNG X 5 X 2 X 7 X 6
#
# 경영학 NNG X 2 X 4 12 18 X 3
#
# 경우 NNG X 3 X X 7 10 X 1133
#
# 경제 NNG X 2 X 1 4 7 2 130
#
# 경제학 NNG X 2 X 6 3 11 X 7
#
# 경주 NNG X 1 X X 1 2 X 2
#
# 경찰 NNG X 1 X 8 1 10 1 43
#
# 경찰관 NNG 1 2 X X 1 4 X 9
#
# 경치 NNG 2 7 5 9 13 36 2 5
#
# 경험 NNG 1 4 X 3 23 31 7 123
#
# 계단 NNG 2 1 X 3 2 8 2 16
#
# 계란 NNG X 6 X 3 10 19 X 29
#
# 계량컵 NNG X 1 X X 1 2 X X
#
# 계산 NNG 1 4 X 4 X 9 3 68
#
# 계절 NNG 3 2 2 9 2 18 18 17
#
# 계획 NNG 19 11 3 15 10 58 29 119
#
# 고개 NNG X 1 X X 1 2 X 32
#
# 고객 NNG X X X 1 1 2 X 13
#
# 고궁 NNG 2 X X X 6 8 X 3
#
# 고기 NNG 6 4 7 10 2 29 1 16
#
# 고대 NNG X 1 X X 1 2 X 2
#
# 고등학교 NNG 3 2 X 5 1 11 6 44
#
# 고등학생 NNG X X X 1 1 2 1 4
#
#
#
# - 15 -
#
# 고모 NNG 1 4 X 2 1 8 X 4
#
# 고모부 NNG X 1 X 1 X 2 X X
#
# 고민 NNG X 1 X 7 15 23 1 122
#
# 고생 NNG X 5 X 1 5 11 X 77
#
# 고속 NNG 1 6 1 1 X 9 X 5
#
# 고속버스 NNG X X X 7 9 16 2 X
#
# 고양이 NNG 7 X 1 2 10 20 2 27
#
# 고장 NNG 1 1 1 3 3 9 3 15
#
# 고추 NNG 1 1 X 3 1 6 X 7
#
# 고추장 NNG 2 1 X 3 X 6 X 2
#
# 고향 NNG 7 4 1 56 77 145 41 31
#
# 골목 NNG 4 3 X X 8 15 X 6
#
# 골프 NNG 2 2 1 2 4 11 X 1
#
# 곰 NNG X 1 1 X X 2 X 1
#
# 곳 NNG 10 53 3 53 76 195 61 7
#
# 곳곳 NNG 1 1 X X X 2 X 11
#
# 공 NNG 6 1 1 1 1 10 1 25
#
# 공간 NNG X 1 X X 10 11 X 131
#
# 공공 NNG 2 1 1 1 1 6 X 20
#
# 공과금 NNG X 1 X 1 X 2 X X
#
# 공기 NNG 1 5 X 5 1 12 11 65
#
# 공동 NNG X 2 X 2 2 6 X 29
#
# 공무원 NNG 1 1 X X 4 6 X 55
#
# 공부 NNG 70 32 32 86 148 368 98 566
#
# 공부방 NNG X X X 5 1 6 X X
#
# 공사 NNG X 5 X 1 3 9 9 10
#
# 공상 NNG X 1 X 1 X 2 X X
#
# 공연 NNG 3 7 X X X 10 17 25
#
# 공원 NNG 26 1 15 42 42 126 70 19
#
# 공장 NNG X X X 1 3 4 X 3
#
# 공중 NNG 3 5 X X X 8 X 9
#
# 공중전화 NNG 5 X 2 X 10 17 X X
#
# 공책 NNG 4 3 2 19 1 29 8 5
#
# 공통점 NNG 1 X X X 1 2 X 38
#
# 공포 NNG X 1 X 4 X 5 X 23
#
# 공학 NNG X X X 2 5 7 X 9
#
# 공항 NNG 4 10 9 6 12 41 41 21
#
#
#
# - 16 -
#
# 공휴일 NNG 3 X X 5 X 8 X 1
#
# 과 NNG 34 2 12 4 5 57 4 4
#
# 과거 NNG X 1 X X 6 7 X 45
#
# 과로 NNG X 2 X 1 X 3 X X
#
# 과일 NNG 7 8 1 14 19 49 37 39
#
# 과자 NNG X 2 X 6 25 33 16 27
#
# 과장 NNG X 4 X 2 X 6 X 67
#
# 과정 NNG 1 X X X 1 2 X 303
#
# 과학 NNG X 2 X 1 X 3 X 38
#
# 관계 NNG X 4 X 1 5 10 X 284
#
# 관광 NNG 1 3 5 2 5 16 4 49
#
# 관광객 NNG X X X 1 5 6 2 5
#
# 관광지 NNG 1 X X 7 5 13 1 8
#
# 관련 NNG X X X 1 11 12 X 160
#
# 관리 NNG 1 X X 2 X 3 X 86
#
# 관심 NNG 3 13 3 3 4 26 13 178
#
# 광고 NNG 8 10 5 4 7 34 4 1
#
# 광고지 NNG X 2 X X 4 6 X X
#
# 광장 NNG X 2 X X 4 6 X 14
#
# 교과서 NNG 2 X X 13 X 15 X 52
#
# 교사 NNG X 1 X X 3 4 X 213
#
# 교수 NNG 1 10 X 3 11 25 X 290
#
# 교실 NNG 62 1 9 33 10 115 13 45
#
# 교육학 NNG X 2 X X 8 10 X 12
#
# 교통 NNG 2 17 3 11 5 38 13 33
#
# 교통수단 NNG X 5 X 3 X 8 X X
#
# 교통편 NNG X 2 X 7 3 12 X X
#
# 교회 NNG 11 2 4 4 X 21 X 1
#
# 구 NNG 3 7 3 2 5 20 9 18
#
# 구경 NNG 11 11 7 29 32 90 31 39
#
# 구두 NNG 14 9 5 9 10 47 37 28
#
# 구름 NNG 4 1 X 6 12 23 3 7
#
# 구멍 NNG X 1 X 1 1 3 X 12
#
# 구석 NNG X 5 X X 1 6 X 18
#
# 구역 NNG X 2 X X 1 3 X 7
#
# 구이 NNG X 1 X X 2 3 X 2
#
# 구입 NNG X 1 X X 1 2 1 13
#
#
#
# - 17 -
#
# 구조 NNG 1 X X X 1 2 X 104
#
# 국 NNG 8 1 1 4 3 17 1 1
#
# 국내 NNG X 2 X 4 X 6 2 47
#
# 국립 NNG 2 1 X X 3 6 X 5
#
# 국문학 NNG 1 1 X 1 X 3 X 8
#
# 국물 NNG 3 2 X 2 X 7 X 17
#
# 국민 NNG 1 2 X X 1 4 X 39
#
# 국수 NNG 3 2 2 1 6 14 X 1
#
# 국어 NNG 1 1 2 1 4 9 12 144
#
# 국적 NNG 2 2 X 6 18 28 X 13
#
# 국제 NNG 9 2 X 5 1 17 1 69
#
# 국철 NNG X 1 X X 1 2 X 1
#
# 귀 NNG X 9 1 3 3 16 X 1
#
# 귀하 NNG X 1 X X 2 3 X 1
#
# 규칙 NNG 2 4 X X 5 11 X 48
#
# 귤 NNG X 2 X 6 10 18 X 18
#
# 그날 NNG 2 X X 4 2 8 2 101
#
# 그동안 NNG 3 X 1 2 23 29 9 3
#
# 그때 NNG X 1 3 8 4 16 3 1050
#
# 그릇 NNG 9 2 4 1 1 17 1 9
#
# 그림 NNG 184 7 2 20 730 943 21 290
#
# 그저께 NNG 1 2 X 3 4 10 X 6
#
# 극장 NNG 27 7 26 21 41 122 36 49
#
# 근처 NNG 26 13 11 27 89 166 37 52
#
# 글 NNG 32 4 5 2 8 51 7 1
#
# 글씨 NNG X 2 X 1 2 5 X 35
#
# 금 NNG 3 1 1 1 16 22 8 1
#
# 금액 NNG X 3 X X 1 4 2 3
#
# 금연 NNG 1 X X X 1 2 X 2
#
# 금요일 NNG 4 15 5 17 10 51 13 101
#
# 금지 NNG X 3 X 1 X 4 1 19
#
# 급 NNG 1 1 X 3 1 6 7 42
#
# 기 NNG 16 2 5 9 1 33 13 2
#
# 기간 NNG 2 6 1 8 7 24 3 111
#
# 기관 NNG X X X 1 1 2 X 149
#
# 기념품 NNG X 1 X 1 X 2 1 10
#
# 기능 NNG X 4 X X 1 5 X 195
#
#
#
# - 18 -
#
# 기대 NNG X 3 X 2 X 5 1 64
#
# 기름 NNG X 1 2 7 X 10 X 25
#
# 기말 NNG X 1 X X 3 4 X 19
#
# 기본 NNG X 1 X X 2 3 1 196
#
# 기분 NNG 7 13 6 17 44 87 27 196
#
# 기사 NNG X 3 X 5 5 13 5 73
#
# 기숙사 NNG 21 5 X 10 28 64 16 25
#
# 기술자 NNG X 1 X X 2 3 X X
#
# 기억 NNG X 4 X 4 1 9 4 296
#
# 기업 NNG X 1 X X 5 6 X 4
#
# 기온 NNG 5 3 X 1 38 47 2 X
#
# 기자 NNG X 2 X 4 9 15 1 4
#
# 기차 NNG 8 8 4 19 7 46 28 37
#
# 기차역 NNG 3 4 X X X 7 5 3
#
# 기차표 NNG 6 X X 1 X 7 11 3
#
# 기침 NNG 4 3 1 8 13 29 5 8
#
# 기타 NNG X 9 X 3 8 20 1 48
#
# 기회 NNG X 5 X 1 1 7 X 97
#
# 긴장 NNG X 3 X X 10 13 X 47
#
# 길 NNG 16 1 7 21 2 47 45 110
#
# 길거리 NNG X 1 X X 2 3 X 10
#
# 길이 NNG X 2 X X 4 6 X 24
#
# 김 NNG X 1 X 1 1 3 X 8
#
# 김밥 NNG 13 X X 11 15 39 6 26
#
# 김치 NNG 18 9 X 13 1 41 17 22
#
# 김치찌개 NNG 3 X 2 8 38 51 6 X
#
# 까만색 NNG 1 8 2 3 21 35 8 6
#
# 껌 NNG 3 1 X 4 X 8 1 4
#
# 껍질 NNG X 3 X 4 X 7 X 1
#
# 꼬리 NNG X X 1 10 X 11 1 4
#
# 꼬마 NNG 2 X 1 1 X 4 X 12
#
# 꽃 NNG 31 6 1 25 1 64 44 1
#
# 꽃다발 NNG X 2 X 5 X 7 X 1
#
# 꽃무늬 NNG X 1 X 3 X 4 X X
#
# 꽃바구니 NNG X 2 X 2 X 4 X X
#
# 꽃집 NNG 2 X X 1 X 3 14 1
#
# 꿈 NNG X 7 4 1 12 24 4 119
#
#
#
# - 19 -
#
# 끈 NNG X 2 X 2 3 7 X 11
#
# 끝 NNG 1 7 X X 8 16 1 708
#
# 나라 NNG 13 18 5 38 57 131 44 782
#
# 나머지 NNG X 2 X X 3 5 X 105
#
# 나무 NNG 4 2 11 3 2 22 21 1
#
# 나물 NNG X 1 X 2 1 4 X 1
#
# 나이 NNG 3 3 1 9 7 23 22 301
#
# 나중 NNG 4 7 4 5 19 39 7 599
#
# 나흘 NNG X 2 X X 1 3 X 1
#
# 낚시 NNG 15 X 2 10 1 28 1 6
#
# 난로 NNG 2 2 1 X X 5 X 3
#
# 날 NNG 2 27 6 4 6 45 2 1
#
# 날씨 NNG 35 28 10 48 198 319 64 37
#
# 날짜 NNG 7 4 X 6 1 18 26 28
#
# 남 NNG 1 5 X 1 31 38 1 1
#
# 남동생 NNG 2 4 X 7 8 21 1 9
#
# 남방 NNG X 1 X X 14 15 X 19
#
# 남부 NNG 3 1 X X 3 7 X 7
#
# 남자 NNG 31 13 29 10 148 231 300 862
#
# 남쪽 NNG X 3 4 4 1 12 2 15
#
# 남편 NNG 3 5 X 3 5 16 4 60
#
# 낮 NNG 8 3 X 2 8 21 8 33
#
# 내과 NNG 2 X X 1 X 3 X 7
#
# 내년 NNG 7 2 X 10 3 22 12 37
#
# 내부 NNG X 1 X X 2 3 X 45
#
# 내용 NNG 5 4 X 1 129 139 19 451
#
# 내일 NNG 52 26 22 70 101 271 128 45
#
# 냄비 NNG X 10 X 3 1 14 X 5
#
# 냄새 NNG 1 1 X 1 1 4 X 75
#
# 냉면 NNG 5 7 14 12 22 60 11 14
#
# 냉장고 NNG 6 11 2 12 3 34 4 18
#
# 네 NNG 3 2 X 5 1 11 X 1
#
# 넥타이 NNG X 6 X 6 15 27 X 5
#
# 노란색 NNG X 6 1 5 16 28 2 13
#
# 노래 NNG 38 14 14 28 47 141 41 184
#
# 노래방 NNG 4 3 X 3 2 12 1 30
#
# 노력 NNG 1 1 X X 6 8 2 95
#
#
#
# - 20 -
#
# 노선 NNG X 1 X 1 12 14 X 6
#
# 노약자 NNG X X X 1 1 2 X X
#
# 노약자석 NNG X X X 1 3 4 X X
#
# 노인 NNG X X X 6 1 7 5 16
#
# 노트 NNG 1 X X X 39 40 X 18
#
# 노트북 NNG 1 1 X 1 X 3 X 19
#
# 녹음 NNG X 1 X 2 2 5 X 278
#
# 녹차 NNG X 2 2 1 X 5 2 13
#
# 놀이 NNG 7 2 X 9 1 19 4 31
#
# 놀이터 NNG X 1 X 2 X 3 1 X
#
# 농구 NNG 3 2 3 8 4 20 12 24
#
# 농구공 NNG 2 X X 1 1 4 X X
#
# 농담 NNG X 1 X X 3 4 X 34
#
# 높이 NNG 1 1 X X X 2 X 8
#
# 높임 NNG 1 X X X 1 2 X X
#
# 누나 NNG 3 6 1 11 16 37 14 88
#
# 눈 NNG 9 14 6 23 1 53 31 1
#
# 눈사람 NNG 1 X X 5 1 7 2 2
#
# 눈싸움 NNG 1 X X 2 X 3 2 X
#
# 느낌 NNG X 1 X 1 16 18 2 174
#
# 능력 NNG X 3 X X 12 15 1 141
#
# 니스 NNG 17 2 21 1 26 67 14 1
#
# 다 NNG 1 11 5 1 1 19 1 1
#
# 다리 NNG 4 7 1 14 1 27 4 2
#
# 다발 NNG 2 2 X 5 X 9 X 1
#
# 다방 NNG 1 X X 1 X 2 X 5
#
# 다음 NNG 106 50 30 53 276 515 84 1
#
# 다이어트 NNG X 2 2 X X 4 X 26
#
# 단 NNG 2 1 X 3 1 7 2 3
#
# 단독 NNG X 3 X X 1 4 X 10
#
# 단발머리 NNG X 1 X X 1 2 X X
#
# 단어 NNG 6 X X 6 69 81 5 233
#
# 단지 NNG X 1 X 1 2 4 X 12
#
# 단풍 NNG 2 X 3 7 4 16 4 2
#
# 달 NNG 11 28 14 30 1 84 37 3
#
# 달걀 NNG X 4 X 2 X 6 X 2
#
# 달러 NNG X 2 X 1 4 7 1 1
#
#
#
# - 21 -
#
# 달력 NNG 4 2 X 3 12 21 5 4
#
# 닭갈비 NNG X X X 6 1 7 X 2
#
# 닭고기 NNG X 1 2 4 X 7 X 1
#
# 담배 NNG 14 13 8 11 5 51 15 71
#
# 답 NNG 18 3 7 3 96 127 1 2
#
# 답장 NNG 1 X 4 3 9 17 5 8
#
# 닷새 NNG X 1 X X 1 2 X 2
#
# 당 NNG 1 23 39 2 4 69 78 12
#
# 당구 NNG X X X 1 1 2 X 7
#
# 당근 NNG X 3 X 2 X 5 X 1
#
# 대답 NNG 15 3 7 X 96 121 1 101
#
# 대리 NNG X 1 X X 12 13 X 17
#
# 대문 NNG X 1 X X 1 2 X 1
#
# 대부분 NNG X 1 X X 2 3 1 134
#
# 대사관 NNG 4 5 19 1 2 31 7 3
#
# 대신 NNG X 2 X X 7 9 1 67
#
# 대중 NNG X 2 X X 2 4 X 32
#
# 대출 NNG X 5 X 1 X 6 X 5
#
# 대표 NNG X 1 X 2 X 3 1 75
#
# 대학 NNG 10 2 3 13 42 70 12 312
#
# 대학교 NNG 12 17 8 17 15 69 32 130
#
# 대학생 NNG 1 X 1 X 1 3 X 40
#
# 대학원 NNG 11 1 X 3 18 33 10 7
#
# 대형 NNG X 2 X X 3 5 X 12
#
# 대화 NNG 13 X X 3 76 92 1 428
#
# 대회 NNG 9 X X 1 5 15 2 53
#
# 댁 NNG 20 4 X X 6 30 7 4
#
# 댄스 NNG X X X 5 6 11 X 11
#
# 덕 NNG X 1 X 2 2 5 X 6
#
# 덕분 NNG X 1 X 7 18 26 X 3
#
# 덤 NNG 3 1 X X X 4 X 1
#
# 데이트 NNG X 6 2 1 1 10 X 9
#
# 도구 NNG X 1 X X 2 3 X 1
#
# 도넛 NNG X 5 X X 1 6 X X
#
# 도둑 NNG 1 1 X X X 2 X 2
#
# 도로 NNG 1 2 X 2 10 15 1 1
#
# 도서관 NNG 36 4 16 42 31 129 62 55
#
#
#
# - 22 -
#
# 도시 NNG 5 10 X 12 2 29 5 1
#
# 도시락 NNG 2 X 1 2 X 5 X 11
#
# 도움 NNG X 6 X 4 5 15 2 121
#
# 도자기 NNG 1 2 X X 3 6 X 7
#
# 도장 NNG X 4 X 4 5 13 X 3
#
# 도착 NNG 12 12 9 20 8 61 19 50
#
# 독서 NNG 1 1 X 3 X 5 X 13
#
# 돈 NNG 13 29 1 39 3 85 36 716
#
# 돈가스 NNG 1 X X 2 X 3 X X
#
# 돌 NNG 1 3 X 1 2 7 2 1
#
# 동 NNG 11 2 1 2 69 85 4 1
#
# 동네 NNG X 2 X 5 X 7 X 77
#
# 동료 NNG X 16 4 3 4 27 X 20
#
# 동물 NNG X 3 X 2 4 9 3 36
#
# 동사 NNG 29 1 X X 6 36 X 1
#
# 동산 NNG X 1 X 4 16 21 X 3
#
# 동생 NNG 2 4 10 7 10 33 1 9
#
# 동아리 NNG 1 X X 4 5 10 X 91
#
# 동안 NNG 3 26 1 2 4 36 9 3
#
# 동양 NNG X 4 X 1 7 12 1 20
#
# 동전 NNG 12 1 X X 10 23 X 10
#
# 동쪽 NNG X 1 1 X 3 5 X 3
#
# 동창 NNG X 4 X 3 X 7 X 10
#
# 동창회 NNG X 2 X 1 X 3 X 8
#
# 동호회 NNG X X X 3 3 6 X 3
#
# 돼지고기 NNG 1 1 1 6 4 13 X 10
#
# 된장찌개 NNG 5 2 X 3 17 27 4 3
#
# 두통 NNG X 1 X 2 4 7 X 1
#
# 뒤 NNG 5 8 4 7 22 46 7 354
#
# 드라마 NNG X 1 X 4 2 7 8 58
#
# 드라이브 NNG X 2 2 X X 4 X 9
#
# 드림 NNG 1 1 X X 2 4 1 X
#
# 듣기 NNG 1 X X 1 19 21 X 3
#
# 등 NNG 2 8 X 1 2 13 1 1
#
# 등록증 NNG X 1 X 2 1 4 X 1
#
# 등산 NNG 41 9 5 11 55 121 28 8
#
# 등산복 NNG 1 X X X 3 4 X X
#
#
#
# - 23 -
#
# 등산화 NNG 4 X X 2 3 9 1 3
#
# 디자인 NNG 1 1 X 6 12 20 2 39
#
# 디지털 NNG X X X 1 1 2 X 14
#
# 딸 NNG 5 1 X 3 10 19 8 78
#
# 딸기 NNG 1 2 X 3 9 15 X 7
#
# 땀 NNG X 1 1 X 5 7 X 22
#
# 때 NNG 32 1 3 8 2 46 3 9
#
# 떡 NNG 1 2 2 1 6 12 7 1
#
# 떡국 NNG X 3 X X 1 4 X 3
#
# 떡볶이 NNG 5 X X 1 X 6 X 27
#
# 뚜껑 NNG X 6 1 X X 7 X 11
#
# 뜻 NNG 1 10 X X 3 14 2 185
#
# 라디오 NNG 2 5 X 1 1 9 X 18
#
# 라면 NNG 6 16 X 4 39 65 X 3
#
# 러닝 NNG X 1 X X 1 2 X 1
#
# 리조트 NNG X X X 1 2 3 X X
#
# 마늘 NNG X 3 7 1 1 12 X 8
#
# 마당 NNG X 1 X 2 2 5 X 1
#
# 마을 NNG X 3 X 1 3 7 X 50
#
# 마음 NNG 4 15 9 12 34 74 19 350
#
# 마장 NNG 1 X X X 2 3 X 1
#
# 마지막 NNG 4 4 1 1 2 12 3 252
#
# 만남 NNG 1 1 X 1 X 3 2 13
#
# 만년필 NNG 1 2 X 3 X 6 X 7
#
# 만두 NNG 2 X X 2 X 4 X 4
#
# 만화 NNG X 2 X 3 X 5 X 55
#
# 말 NNG 1 1 1 2 28 33 67 44
#
# 말씀 NNG X 21 6 15 26 68 23 597
#
# 맛 NNG 2 6 X 16 1 25 11 5
#
# 맞은편 NNG X 3 X X 2 5 4 3
#
# 매매 NNG 1 X X X 3 4 X 2
#
# 매일 NNG 1 1 X X 4 6 1 14
#
# 매장 NNG 1 2 X 3 1 7 4 33
#
# 매진 NNG 6 2 X X X 8 X 3
#
# 맥주 NNG 8 7 3 12 1 31 X 47
#
# 머리 NNG 34 2 7 11 1 55 16 2
#
# 머리카락 NNG X X X 1 1 2 X 4
#
#
#
# - 24 -
#
# 먹 NNG 1 X 1 1 4 7 X 18
#
# 먼지 NNG X X X 4 2 6 X 8
#
# 멍 NNG 1 1 X 1 1 4 X 12
#
# 메뉴 NNG 7 4 4 X 3 18 2 15
#
# 메모 NNG 5 7 X 3 46 61 12 6
#
# 메시지 NNG 3 1 X 19 7 30 2 20
#
# 메일 NNG 11 3 1 1 33 49 2 42
#
# 며칠 NNG 9 3 5 10 4 31 9 86
#
# 면 NNG 5 7 14 1 3 30 11 3
#
# 면도 NNG X 4 X X 1 5 X 2
#
# 면적 NNG X 1 X 1 1 3 X 3
#
# 면접 NNG 2 1 X X 7 10 X 85
#
# 면허증 NNG X 3 X 1 X 4 X 11
#
# 명사 NNG 32 X X X 12 44 X 2
#
# 명절 NNG 1 1 X X X 2 3 12
#
# 모니터 NNG X X X 1 1 2 X 34
#
# 모델 NNG X 2 X 3 3 8 X 74
#
# 모두 NNG X 2 X 1 X 3 1 35
#
# 모레 NNG 6 2 X 3 6 17 1 5
#
# 모습 NNG 1 1 X X 2 4 7 1
#
# 모양 NNG 1 17 X 1 17 36 6 62
#
# 모임 NNG 2 1 X 25 11 39 19 70
#
# 모자 NNG 14 7 4 3 20 48 33 26
#
# 모퉁이 NNG X 1 X X 1 2 X X
#
# 목 NNG 4 3 8 15 3 33 1 1
#
# 목걸이 NNG 1 2 X 1 1 5 X 5
#
# 목도리 NNG 1 X X 1 6 8 X X
#
# 목록 NNG X 1 X X 1 2 X 13
#
# 목소리 NNG 3 2 X 6 1 12 1 164
#
# 목요일 NNG 4 2 8 2 3 19 6 54
#
# 목욕탕 NNG X 1 3 X X 4 1 18
#
# 목적 NNG X 5 X X 3 8 1 135
#
# 목적지 NNG X 1 X X 1 2 X 9
#
# 몸 NNG X 2 X 10 1 13 14 164
#
# 몸살 NNG X 1 X X 2 3 X 2
#
# 못 NNG 1 1 1 X 2 5 1 3
#
# 무 NNG 4 1 11 3 2 21 21 1
#
#
#
# - 25 -
#
# 무덤 NNG 2 1 X X X 3 X 6
#
# 무료 NNG 6 1 X 1 X 8 3 18
#
# 무릎 NNG 4 1 X 2 5 12 X 9
#
# 무리 NNG 3 X X 2 1 6 X 36
#
# 무역 NNG 1 18 13 8 X 40 4 1
#
# 무용 NNG X 4 X 2 X 6 X 21
#
# 문 NNG 3 1 1 2 5 12 1 2
#
# 문구 NNG X 3 1 X 1 5 X 13
#
# 문구점 NNG X X 3 1 X 4 1 X
#
# 문방구 NNG 3 X X 2 4 9 X X
#
# 문법 NNG 10 1 1 X 31 43 X 98
#
# 문의 NNG 1 2 X X 7 10 3 8
#
# 문자 NNG X 1 X 9 1 11 X 1
#
# 문장 NNG 2 X X X 7 9 X 112
#
# 문제 NNG X 8 X 6 8 22 2 1121
#
# 문학 NNG 1 1 X 1 3 6 X 8
#
# 문화 NNG 15 9 6 5 53 88 18 274
#
# 물 NNG 4 2 7 1 1 15 15 4
#
# 물가 NNG X 1 X X 5 6 X 11
#
# 물건 NNG 24 14 X 38 28 104 68 62
#
# 물고기 NNG 1 X X 4 2 7 1 12
#
# 물냉면 NNG 4 1 X 5 X 10 X X
#
# 물론 NNG X 8 X X 1 9 X 7
#
# 물소리 NNG X 1 X 1 X 2 X X
#
# 미 NNG 12 2 6 1 1 22 1 1
#
# 미래 NNG X 2 X 1 1 4 X 33
#
# 미술 NNG X 1 X X 1 2 X 19
#
# 미술관 NNG 4 1 X 1 4 10 6 2
#
# 미안 NNG 15 16 14 9 25 79 48 114
#
# 미용실 NNG 7 X 1 3 5 16 2 16
#
# 민박 NNG 2 2 X 5 X 9 X X
#
# 민속 NNG X 4 1 X X 5 X 3
#
# 민속촌 NNG 4 5 X X 9 18 5 X
#
# 밀가루 NNG X 1 X 2 2 5 X 10
#
# 밑 NNG X 11 X 1 33 45 3 232
#
# 밑줄 NNG X X X 1 1 2 1 4
#
# 바구니 NNG X 2 X 2 11 15 X 9
#
#
#
# - 26 -
#
# 바나나 NNG 7 1 X 4 4 16 1 13
#
# 바다 NNG 4 11 5 31 14 65 29 2
#
# 바닥 NNG 2 1 X X 4 7 2 3
#
# 바닷가 NNG 1 3 X 7 12 23 4 8
#
# 바람 NNG 3 16 3 12 2 36 10 3
#
# 바보 NNG X X X 3 1 4 X 57
#
# 바이올린 NNG X 3 X 2 2 7 X 2
#
# 바지 NNG 24 12 9 1 14 60 22 1
#
# 박물관 NNG 5 1 9 2 27 44 28 9
#
# 박사 NNG 1 X X 4 1 6 X 82
#
# 박수 NNG 1 X X 2 2 5 X 10
#
# 밖 NNG 6 6 2 12 30 56 32 1
#
# 반 NNG 1 1 9 25 2 38 16 2
#
# 반납 NNG X X X 3 3 6 X 2
#
# 반말 NNG X X X 1 3 4 X 16
#
# 반바지 NNG 1 3 X 1 6 11 X 3
#
# 반지 NNG 2 5 X 2 X 9 X 28
#
# 반쯤 NNG X X X 3 1 4 X X
#
# 반찬 NNG 6 1 1 2 1 11 X 4
#
# 발 NNG 2 1 2 5 5 15 1 4
#
# 발목 NNG X 1 X X 14 15 X 4
#
# 발음 NNG 14 7 X 2 65 88 2 221
#
# 발전 NNG X 1 X 1 4 6 X 54
#
# 발표 NNG X X X 2 33 35 1 246
#
# 밤 NNG 22 12 8 17 1 60 25 1
#
# 밥 NNG 13 14 7 1 1 36 2 26
#
# 밥상 NNG X X X 1 2 3 X 3
#
# 방 NNG 26 30 11 44 4 115 67 64
#
# 방면 NNG X X X 3 2 5 X 3
#
# 방문 NNG 1 6 X 2 X 9 1 17
#
# 방법 NNG 2 10 X 16 34 62 15 386
#
# 방송 NNG 2 4 X 4 6 16 23 156
#
# 방송국 NNG 3 1 X 1 X 5 1 25
#
# 방송학 NNG X X X 2 3 5 X X
#
# 방안 NNG X 1 X X 1 2 X 16
#
# 방울 NNG X 1 X 1 X 2 X 1
#
# 방학 NNG 15 3 18 36 57 129 28 153
#
#
#
# - 27 -
#
# 방해 NNG 1 1 X X X 2 X 31
#
# 방향 NNG X X X 3 4 7 1 1
#
# 방화 NNG X X X 1 2 3 X 2
#
# 밭 NNG 1 X X 1 1 3 2 2
#
# 배 NNG 14 13 8 11 3 49 15 7
#
# 배경 NNG X 1 X X 3 4 X 56
#
# 배구 NNG 2 X 1 1 X 4 2 2
#
# 배낭 NNG 4 8 X 5 4 21 X 11
#
# 배달 NNG 35 2 3 6 X 46 7 18
#
# 배드민턴 NNG X X X 1 3 4 X X
#
# 배우 NNG X 6 X 1 4 11 6 23
#
# 배웅 NNG 1 1 X X X 2 X 1
#
# 배추 NNG X 5 X 2 1 8 X 2
#
# 배추김치 NNG X 1 X X 1 2 X X
#
# 배치 NNG X X X 1 5 6 X 24
#
# 배탈 NNG 3 2 X 4 19 28 X 1
#
# 백화점 NNG 15 16 11 52 31 125 63 92
#
# 밴드 NNG 3 X X X 5 8 X 88
#
# 버섯 NNG X 2 X 1 1 4 X 3
#
# 버스 NNG 21 29 27 7 1 85 2 1
#
# 버터 NNG X 1 X 1 X 2 X 8
#
# 번개 NNG 1 X X X 6 7 X 8
#
# 번역 NNG X 1 X 1 19 21 2 48
#
# 번지 NNG X 5 3 1 2 11 2 2
#
# 번호 NNG 51 38 11 27 12 139 6 2
#
# 벌 NNG 3 1 X 7 1 12 X 11
#
# 범죄 NNG 1 X X 1 X 2 X 2
#
# 법 NNG 10 1 1 16 1 29 15 1
#
# 법학 NNG X 2 X 2 8 12 X 2
#
# 벚꽃 NNG X X X 2 3 5 X 14
#
# 베란다 NNG X X X 1 2 3 X 2
#
# 벤치 NNG X X X 1 3 4 X 3
#
# 벨 NNG X 1 X 2 2 5 1 3
#
# 벽 NNG X 3 X 4 6 13 X 1
#
# 벽시계 NNG 1 X X X 1 2 X X
#
# 변비 NNG X 2 X 2 X 4 X 6
#
# 변호사 NNG 1 1 X 4 6 12 X 25
#
#
#
# - 28 -
#
# 별 NNG 1 2 X 2 1 6 X 1
#
# 별일 NNG X X X 1 9 10 X 1
#
# 병 NNG 1 1 2 28 1 33 4 1
#
# 병실 NNG X 1 X 1 X 2 X 1
#
# 병원 NNG 19 5 7 29 44 104 58 1
#
# 보 NNG 1 3 X 3 14 21 1 1
#
# 보고서 NNG X X X 1 7 8 X 22
#
# 보기 NNG 9 1 X 1 275 286 X 3
#
# 보도 NNG 5 2 X 7 36 50 X 12
#
# 보라색 NNG X 1 1 X 6 8 X 10
#
# 보세 NNG X 1 X X 1 2 X X
#
# 보증금 NNG X 1 X 4 X 5 X 2
#
# 보통 NNG 2 21 5 9 13 50 4 102
#
# 보험 NNG 1 X X 7 X 8 X 15
#
# 보험료 NNG X 1 X 2 X 3 X 2
#
# 보호 NNG X X X 1 3 4 X 46
#
# 복도 NNG X 1 X X 3 4 X 1
#
# 복사 NNG X 1 X 3 X 4 X 24
#
# 복사기 NNG X 1 X 1 X 2 X X
#
# 복숭아 NNG X 1 X X 6 7 X 4
#
# 볶음밥 NNG 1 X X 3 X 4 2 5
#
# 본인 NNG X X X 2 1 3 X 54
#
# 볼링 NNG 1 1 X X 5 7 X 17
#
# 볼펜 NNG 3 5 3 9 2 22 1 18
#
# 봄 NNG 1 8 5 20 1 35 13 55
#
# 봉지 NNG X 2 X X 9 11 X 2
#
# 봉투 NNG X 1 X 3 7 11 1 7
#
# 부 NNG 70 1 32 1 3 107 98 2
#
# 부동산 NNG X 1 X 4 16 21 X 9
#
# 부모 NNG 29 5 4 27 1 66 43 178
#
# 부부 NNG 1 9 X 1 2 13 1 62
#
# 부분 NNG 2 1 X X 1 4 1 134
#
# 부엌 NNG 1 4 6 3 2 16 1 9
#
# 부인 NNG 6 1 X X 1 8 X 1
#
# 부장 NNG X 1 X X 1 2 X 5
#
# 부정 NNG 1 1 X X X 2 X 25
#
# 부지런 NNG 2 3 X X X 5 3 1
#
#
#
# - 29 -
#
# 부채 NNG 3 1 X X 1 5 X 3
#
# 부츠 NNG X 1 X X 3 4 X 1
#
# 부케 NNG X 2 X 2 X 4 X 12
#
# 부탁 NNG 15 20 6 5 82 128 23 72
#
# 북 NNG 1 1 X 1 1 4 X 2
#
# 북쪽 NNG 3 1 1 X 3 8 X 2
#
# 분 NNG 7 13 6 17 1 44 27 3
#
# 분위기 NNG 1 1 X 6 3 11 1 206
#
# 분홍색 NNG X 1 X 1 13 15 X 12
#
# 불 NNG 8 14 1 7 7 37 6 1
#
# 불고기 NNG 27 4 18 34 27 110 24 3
#
# 불편 NNG 1 10 5 6 21 43 12 40
#
# 붕대 NNG X X X 1 7 8 X X
#
# 블라우스 NNG 1 2 X 1 13 17 X 4
#
# 비 NNG 3 2 4 8 3 20 1 1
#
# 비교 NNG 1 1 X X 6 8 X 131
#
# 비누 NNG X 4 X 2 16 22 1 6
#
# 비닐 NNG X 2 X X 1 3 X 7
#
# 비디오 NNG 10 4 3 2 X 19 5 1
#
# 비밀 NNG 3 10 X 4 4 21 X 24
#
# 비빔냉면 NNG X 2 X 1 X 3 X X
#
# 비빔밥 NNG 23 5 X 18 24 70 30 7
#
# 비서 NNG X 5 X 3 X 8 X 8
#
# 비용 NNG X 2 X 2 X 4 1 2
#
# 비자 NNG X X 2 6 1 9 X 4
#
# 비타민 NNG X 4 X 2 X 6 X 34
#
# 비행기 NNG 8 19 19 9 2 57 34 60
#
# 빈대떡 NNG 1 2 X X X 3 X 2
#
# 빈칸 NNG 20 X X X 2 22 X 1
#
# 빌딩 NNG X 1 26 2 17 46 6 1
#
# 빠 NNG 1 2 X 2 14 19 2 2
#
# 빨간색 NNG X 6 3 6 17 32 1 22
#
# 빨래 NNG 1 2 3 5 11 22 8 11
#
# 빵 NNG 13 3 2 7 1 26 17 1
#
# 빵집 NNG 6 X X 2 X 8 9 1
#
# 뼈 NNG X 1 1 1 X 3 X 1
#
# 뽀뽀 NNG X X 1 X 3 4 X 4
#
#
#
# - 30 -
#
# 뿔 NNG 2 X X X 2 4 1 6
#
# 삐삐 NNG X 2 1 X X 3 X 8
#
# 사거리 NNG 16 9 X 3 20 48 5 1
#
# 사계절 NNG 1 2 X 3 2 8 X 1
#
# 사고 NNG X 1 X 2 X 3 5 2
#
# 사과 NNG 13 4 7 11 27 62 38 32
#
# 사기 NNG X 1 X 1 3 5 X 1
#
# 사람 NNG 1 176 47 5 1 230 2 2
#
# 사랑 NNG 5 6 3 12 1 27 17 203
#
# 사면 NNG X 1 X X 1 2 X X
#
# 사무실 NNG 3 6 17 6 8 40 38 32
#
# 사물 NNG X 1 X X 4 5 X 6
#
# 사실 NNG X 3 X 2 3 8 X 91
#
# 사업 NNG X 1 X 1 2 4 X 83
#
# 사업가 NNG X 2 X X 1 3 X 6
#
# 사용 NNG X 19 X 9 27 55 20 1
#
# 사우나 NNG 1 2 1 X X 4 X 1
#
# 사원 NNG 1 4 3 1 36 45 5 1
#
# 사이 NNG 5 3 4 1 14 27 3 185
#
# 사이다 NNG X X 2 X 1 3 X 4
#
# 사이즈 NNG 1 X X X 11 12 X 21
#
# 사일 NNG X 1 X 1 2 4 X 7
#
# 사장 NNG X 6 X 4 9 19 8 2
#
# 사전 NNG 21 3 1 28 9 62 24 1
#
# 사진 NNG 1 25 11 30 217 284 55 193
#
# 사진관 NNG 5 X X X 4 9 1 3
#
# 사진기 NNG 4 4 X 1 X 9 13 2
#
# 사촌 NNG X 1 X 9 X 10 X 16
#
# 사탕 NNG 3 X X 1 11 15 X 15
#
# 사항 NNG X 5 X X 5 10 2 65
#
# 사회 NNG 2 2 X X X 4 1 391
#
# 사회학 NNG X 2 X X 5 7 X 16
#
# 사흘 NNG 3 3 X 2 5 13 X 6
#
# 산 NNG 1 4 5 4 1 15 3 1
#
# 산꼭대기 NNG X 4 X X 5 9 X X
#
# 산책 NNG 2 1 8 10 17 38 17 3
#
# 살 NNG 1 1 X 3 1 6 3 1
#
#
#
# - 31 -
#
# 삶다 NNG X 1 X 1 X 2 X X
#
# 삼 NNG 2 6 X 2 2 12 7 1
#
# 삼거리 NNG X 1 X X 13 14 X X
#
# 삼계탕 NNG 1 4 2 10 23 40 4 4
#
# 삼촌 NNG 2 4 X 3 X 9 1 2
#
# 상 NNG 2 1 10 3 6 22 1 7
#
# 상가 NNG 1 X X 1 5 7 X 5
#
# 상의 NNG X 1 X X 1 2 X 7
#
# 상자 NNG 3 11 X 3 1 18 X 1
#
# 상차림 NNG 1 X X X 2 3 X X
#
# 상처 NNG 1 1 X 2 11 15 X 37
#
# 상품 NNG 1 3 X 2 4 10 5 84
#
# 상황 NNG 5 3 X X 11 19 X 232
#
# 새 NNG 1 1 X 1 1 4 X 75
#
# 새마을호 NNG 1 4 X 1 X 6 2 X
#
# 새벽 NNG X 5 X 2 2 9 X 1
#
# 새우 NNG X 2 X 7 X 9 X 16
#
# 새집 NNG X 1 X X 3 4 X X
#
# 색 NNG 1 3 1 2 10 17 1 8
#
# 색깔 NNG 2 1 1 1 34 39 10 112
#
# 샌들 NNG 2 1 X X X 3 X X
#
# 샐러드 NNG X 2 X 2 X 4 X 10
#
# 생각 NNG 13 37 8 29 85 172 33 1
#
# 생강 NNG X 2 X 1 X 3 X 1
#
# 생년월일 NNG X 1 X 2 X 3 X X
#
# 생리통 NNG X 1 X X 2 3 X X
#
# 생선 NNG 5 X 1 17 1 24 3 3
#
# 생신 NNG 3 8 X 2 2 15 5 4
#
# 생일 NNG 64 35 15 50 8 172 43 64
#
# 생활 NNG 7 24 5 15 2 53 35 7
#
# 샤워 NNG X 10 5 3 2 20 5 20
#
# 샤워실 NNG X X X 1 2 3 3 6
#
# 서랍 NNG 3 4 X X 1 8 X 2
#
# 서로 NNG X 1 X X 2 3 2 55
#
# 서류 NNG X 3 3 5 1 12 X 9
#
# 서명 NNG X 4 X 3 13 20 X 16
#
# 서비스 NNG X X X 2 1 3 X 135
#
#
#
# - 32 -
#
# 서양 NNG 1 1 X 3 23 28 X 2
#
# 서재 NNG X 3 X 1 X 4 X X
#
# 서점 NNG 19 5 13 13 29 79 43 6
#
# 서쪽 NNG X X X 1 8 9 X 2
#
# 선 NNG 5 1 1 1 51 59 1 2
#
# 선글라스 NNG 1 1 X 2 X 4 X X
#
# 선물 NNG 42 35 3 45 11 136 60 91
#
# 선배 NNG X 1 X 7 3 11 1 186
#
# 선생 NNG 154 18 19 75 75 341 59 1005
#
# 선수 NNG 3 X X 5 8 16 1 332
#
# 선약 NNG X 1 X 2 X 3 X X
#
# 선택 NNG 4 7 X 1 2 14 X 140
#
# 선풍기 NNG X 1 X 1 X 2 X 4
#
# 설거지 NNG 1 3 2 5 X 11 1 22
#
# 설날 NNG 4 1 X 2 X 7 3 2
#
# 설렁탕 NNG X X X 2 1 3 X 2
#
# 설명 NNG 6 1 2 9 77 95 11 291
#
# 설사 NNG X X X 2 13 15 X 2
#
# 설탕 NNG 1 1 7 1 X 10 2 12
#
# 섬 NNG 2 8 5 4 6 25 X 3
#
# 성 NNG 1 3 X 1 1 6 1 2
#
# 성격 NNG 3 16 X 3 3 25 7 147
#
# 성명 NNG X 2 X 1 X 3 X 1
#
# 성별 NNG 1 2 X 1 X 4 X 19
#
# 성인 NNG X 2 X X 1 3 2 15
#
# 성함 NNG X 7 X 3 2 12 X 6
#
# 세 NNG 2 1 X 1 12 16 X 2
#
# 세계 NNG 2 7 X 6 1 16 2 349
#
# 세기 NNG X 3 X 1 X 4 X 1
#
# 세로 NNG 1 3 X X X 4 X 4
#
# 세상 NNG X 1 X 1 1 3 X 152
#
# 세수 NNG 2 2 5 8 3 20 X 6
#
# 세일 NNG X 1 X 9 2 12 X 1
#
# 세제 NNG X 1 X 1 X 2 X 1
#
# 세차 NNG X X X 1 2 3 X 3
#
# 세탁 NNG X 5 1 1 1 8 3 X
#
# 세탁기 NNG 3 1 4 3 X 11 X 4
#
#
#
# - 33 -
#
# 세탁소 NNG 6 3 X 2 2 13 X 3
#
# 센터 NNG 1 4 7 2 2 16 X 16
#
# 셔츠 NNG 1 10 X 2 34 47 1 3
#
# 소 NNG 6 1 1 2 7 17 1 4
#
# 소개 NNG 19 14 8 13 88 142 37 131
#
# 소고기 NNG X X 6 3 2 11 X 4
#
# 소금 NNG 1 1 2 5 X 9 X 2
#
# 소년 NNG X 5 X X 2 7 X 10
#
# 소독 NNG X 2 X X 8 10 X 3
#
# 소독약 NNG X 1 X 3 2 6 X 1
#
# 소라 NNG X 3 29 X X 32 X 1
#
# 소리 NNG 3 2 6 6 9 26 1 3
#
# 소설 NNG 1 1 X 1 X 3 4 58
#
# 소설가 NNG X 1 X 1 X 2 X 11
#
# 소설책 NNG X X X 2 7 9 2 X
#
# 소스 NNG X 3 X 5 X 8 X 1
#
# 소식 NNG 4 3 X X 4 11 13 13
#
# 소주 NNG 1 X X 1 1 3 X 59
#
# 소파 NNG X 8 X 2 4 14 X 11
#
# 소포 NNG 9 X X 3 23 35 6 1
#
# 소풍 NNG X 2 7 4 2 15 7 2
#
# 소화 NNG X 2 X 6 18 26 X 28
#
# 소화제 NNG X 1 X 2 X 3 X 1
#
# 속 NNG 1 1 1 1 1 5 2 1
#
# 속도 NNG 1 X X X 4 5 X 8
#
# 속옷 NNG 2 1 X 1 X 4 X 3
#
# 손 NNG 20 1 2 25 1 49 53 4
#
# 손가락 NNG 3 2 X X 7 12 X 13
#
# 손님 NNG 1 2 X 1 26 30 1 2
#
# 손목 NNG 1 X X X 4 5 X 10
#
# 손목시계 NNG X 1 X X 1 2 1 X
#
# 손바닥 NNG 2 X X X 4 6 X 5
#
# 손수건 NNG X 2 X 6 2 10 X 1
#
# 송별회 NNG X 1 X 3 X 4 X 1
#
# 송이 NNG 3 1 X 9 8 21 3 3
#
# 쇼 NNG X X X 1 2 3 X 12
#
# 쇼핑 NNG 2 19 7 15 14 57 10 5
#
#
#
# - 34 -
#
# 수 NNG 8 4 2 15 3 32 2 1
#
# 수건 NNG X 2 X 6 2 10 2 4
#
# 수단 NNG X 5 X 3 7 15 X 56
#
# 수도 NNG 1 3 X 4 21 29 X 3
#
# 수리 NNG X 3 X X 1 4 3 5
#
# 수박 NNG 2 4 X 4 7 17 1 7
#
# 수상 NNG X 9 X 1 X 10 X 3
#
# 수수료 NNG X 2 X 3 X 5 X 2
#
# 수술 NNG X 1 X 3 X 4 X 43
#
# 수업 NNG 13 12 16 19 27 87 13 492
#
# 수영 NNG 8 28 8 19 24 87 43 51
#
# 수영복 NNG X 6 1 1 X 8 X 8
#
# 수영장 NNG 1 8 9 1 3 22 21 14
#
# 수요일 NNG 4 8 8 5 4 29 15 28
#
# 수저 NNG X 2 X 2 X 4 X X
#
# 수지 NNG X 4 X X 3 7 2 X
#
# 수집 NNG 3 X X X 1 4 2 15
#
# 수첩 NNG 17 3 X 4 4 28 5 7
#
# 수표 NNG X 5 X X 1 6 X 3
#
# 수학 NNG X 4 X 3 X 7 X 89
#
# 수화기 NNG X 2 X X 1 3 X 1
#
# 숙박 NNG X 2 X 7 X 9 X 4
#
# 숙박비 NNG X 2 X X 3 5 X X
#
# 숙소 NNG X 5 X X 2 7 X 16
#
# 숙제 NNG 24 7 14 26 13 84 16 56
#
# 순두부찌개NNG 2 X X 2 X 4 X X
#
# 순서 NNG 1 1 X X 7 9 X 53
#
# 숟가락 NNG 1 X 7 8 1 17 2 9
#
# 술 NNG 15 2 21 3 1 42 4 132
#
# 술집 NNG X 3 3 3 X 9 X 18
#
# 숫자 NNG 3 X X X 2 5 X 88
#
# 슈퍼 NNG X 3 X X 4 7 X 4
#
# 슈퍼마켓 NNG 2 2 X 4 20 28 12 1
#
# 스노보드 NNG X X X 1 1 2 X X
#
# 스웨터 NNG X 1 2 6 8 17 X 2
#
# 스카프 NNG X 5 X 1 X 6 X 4
#
# 스케이트 NNG X X 2 3 3 8 X 2
#
#
#
# - 35 -
#
# 스케줄 NNG X 1 1 X X 2 X 4
#
# 스크린 NNG X X X 1 1 2 X 8
#
# 스키 NNG 2 11 4 15 20 52 3 2
#
# 스키장 NNG 2 1 X 3 1 7 3 5
#
# 스타킹 NNG 1 1 X 2 X 4 X 5
#
# 스트레스 NNG 2 21 X 4 4 31 2 73
#
# 스파게티 NNG 2 10 2 8 X 22 X 6
#
# 스포츠 NNG 2 4 X 4 X 10 1 23
#
# 슬리퍼 NNG 1 2 X X X 3 X 1
#
# 슬픔 NNG 1 1 X X X 2 X 5
#
# 습 NNG 1 1 4 6 7 19 7 1
#
# 습관 NNG 2 4 X X 4 10 2 31
#
# 습기 NNG X 2 X 1 X 3 X 5
#
# 승진 NNG X 1 X 1 2 4 X 1
#
# 시 NNG 15 2 2 1 142 162 1 4
#
# 시간 NNG 58 103 49 105 176 491 207 1338
#
# 시간표 NNG X 1 1 X X 2 1 19
#
# 시계 NNG 1 1 6 10 16 34 1 45
#
# 시골 NNG 1 2 X 6 9 18 9 38
#
# 시내 NNG 7 3 X 4 10 24 8 1
#
# 시내버스 NNG X X X 3 1 4 1 X
#
# 시대 NNG X 4 X 2 X 6 X 1
#
# 시디 NNG X X X 1 2 3 X 2
#
# 시민 NNG X 5 X 2 1 8 1 82
#
# 시설 NNG X 4 6 7 11 28 X 18
#
# 시외 NNG 9 X X 2 X 11 X X
#
# 시월 NNG 2 1 X 3 1 7 3 24
#
# 시작 NNG 14 24 7 16 19 80 48 406
#
# 시장 NNG 42 3 4 42 43 134 64 93
#
# 시청 NNG 2 2 7 6 25 42 16 22
#
# 시험 NNG 20 25 12 24 2 83 31 460
#
# 시험지 NNG 2 1 X X X 3 X 11
#
# 식구 NNG X 1 X 1 X 2 X 18
#
# 식당 NNG 54 23 39 42 96 254 78 27
#
# 식료품 NNG X 1 X 2 X 3 X 5
#
# 식빵 NNG 3 X X 1 1 5 X 2
#
# 식사 NNG 8 59 20 25 16 128 36 61
#
#
#
# - 36 -
#
# 식탁 NNG 7 3 X 1 1 12 1 3
#
# 식품 NNG X 2 X 1 X 3 X 13
#
# 식혜 NNG X 1 X 2 X 3 X X
#
# 식후 NNG X 1 X X 6 7 X 3
#
# 신고 NNG 3 X X 3 X 6 X 33
#
# 신랑 NNG X X X 4 1 5 X 46
#
# 신문 NNG 18 11 1 21 25 76 34 99
#
# 신발 NNG 7 4 2 6 10 29 17 51
#
# 신부 NNG X X X 6 1 7 X 20
#
# 신분증 NNG X 5 X 7 6 18 X 4
#
# 신용 NNG 1 4 X X 1 6 X 3
#
# 신입 NNG X 3 X 1 X 4 X 9
#
# 신청 NNG 8 1 X 11 5 25 1 75
#
# 신청서 NNG X 13 X 3 14 30 1 3
#
# 신호 NNG X 1 X 2 X 3 X 46
#
# 신호등 NNG 2 1 X 1 X 4 X 2
#
# 신혼 NNG 1 3 X 6 X 10 X 31
#
# 실 NNG 7 7 10 2 3 29 3 2
#
# 실내 NNG X 3 X 1 1 5 1 3
#
# 실례 NNG 4 15 7 11 16 53 27 8
#
# 실수 NNG 2 2 4 2 7 17 4 56
#
# 심리학 NNG X 1 X X 3 4 X 1
#
# 십이월 NNG 1 X 1 2 1 5 1 16
#
# 십일월 NNG 1 X X 1 1 3 X 14
#
# 싱크대 NNG X 2 X X 1 3 X X
#
# 쌀 NNG 4 3 X 3 X 10 3 1
#
# 쓰기 NNG 1 X X X 15 16 X 8
#
# 쓰레기 NNG 2 1 X 3 X 6 4 17
#
# 씨 NNG 35 2 10 1 20 68 64 35
#
# 아가씨 NNG 1 X 19 1 X 21 X 49
#
# 아기 NNG 5 8 1 4 4 22 X 44
#
# 아나운서 NNG X 2 X 2 X 4 X 16
#
# 아내 NNG 3 5 X 2 8 18 2 29
#
# 아들 NNG X 1 X 18 8 27 1 1
#
# 아래 NNG 6 1 4 2 54 67 4 71
#
# 아르바이트NNG 2 2 8 10 15 37 3 125
#
# 아버님 NNG X 1 X 1 X 2 X 18
#
#
#
# - 37 -
#
# 아버지 NNG 26 17 12 67 35 157 32 6
#
# 아이 NNG 21 11 5 41 15 93 61 1
#
# 아이디어 NNG X 1 X 1 1 3 X 14
#
# 아이스크림NNG 1 1 X 5 6 13 2 16
#
# 아저씨 NNG 32 X 16 4 20 72 10 221
#
# 아주머니 NNG 17 6 1 7 4 35 5 3
#
# 아줌마 NNG X 1 3 3 1 8 X 140
#
# 아침 NNG 51 32 26 34 42 185 70 235
#
# 아파트 NNG 19 11 7 14 9 60 25 37
#
# 악기 NNG X 1 X X 5 6 X 1
#
# 안 NNG 3 26 1 2 1 33 9 11
#
# 안개 NNG 1 2 X 1 2 6 1 6
#
# 안경 NNG 7 1 2 X 8 18 14 1
#
# 안경점 NNG 1 1 X X X 2 X 3
#
# 안내 NNG 2 5 5 9 10 31 53 10
#
# 안녕 NNG 53 45 21 29 51 199 30 66
#
# 안부 NNG X 1 X 1 11 13 X 28
#
# 알약 NNG X 1 X X 1 2 X X
#
# 압정 NNG X 1 X X 1 2 X X
#
# 앞 NNG 46 2 14 55 79 196 58 4
#
# 앞쪽 NNG X X X 2 2 4 1 22
#
# 액세서리 NNG X 3 X 1 1 5 X X
#
# 액션 NNG X 1 2 2 X 5 X 19
#
# 앨범 NNG X 1 X X 2 3 X 6
#
# 야구 NNG 5 7 3 12 18 45 13 12
#
# 야채 NNG 1 5 X 1 1 8 X 23
#
# 약 NNG 2 3 8 2 15 30 1 6
#
# 약국 NNG 15 7 3 3 38 66 64 7
#
# 약도 NNG X X X 1 6 7 X X
#
# 약사 NNG X 6 X X 22 28 1 8
#
# 약속 NNG 33 17 22 64 32 168 85 56
#
# 약수 NNG 1 X X X 5 6 X 1
#
# 양 NNG 1 1 X 1 2 5 1 4
#
# 양념 NNG X 6 X 2 X 8 X 5
#
# 양말 NNG 3 1 X 3 3 10 1 1
#
# 양복 NNG 10 2 X 2 27 41 X 17
#
# 양식 NNG 4 X X 2 X 6 X 11
#
#
#
# - 38 -
#
# 양파 NNG X 5 1 4 X 10 X 27
#
# 얘기 NNG X X X 5 1 6 3 3408
#
# 어깨 NNG 1 1 3 1 16 22 X 30
#
# 어디 NNG 1 X X X 1 2 X 1
#
# 어른 NNG 1 6 X 4 1 12 9 61
#
# 어린이 NNG 4 X X 5 3 12 6 6
#
# 어머니 NNG 42 17 16 35 52 162 45 10
#
# 어머님 NNG X 1 X 1 X 2 X 28
#
# 어제 NNG 42 22 23 47 63 197 59 53
#
# 어젯밤 NNG X X 3 X 1 4 X 3
#
# 어휘 NNG 3 X X X 6 9 X 84
#
# 언니 NNG 1 3 1 26 24 55 13 643
#
# 언어 NNG X 5 X 2 35 42 X 695
#
# 언제쯤 NNG 1 X X 1 1 3 X X
#
# 얼 NNG 1 X X 1 7 9 X 2
#
# 얼굴 NNG 6 18 8 4 75 111 9 215
#
# 얼마 NNG 27 20 19 39 33 138 27 290
#
# 얼음 NNG X 1 X 1 9 11 X 6
#
# 엄마 NNG 1 2 1 6 1 11 2 5
#
# 엉덩이 NNG X 1 X X 1 2 X 13
#
# 에 NNG 1 X X 1 X 2 1 2
#
# 에게 NNG X 1 1 X X 2 3 X
#
# 에어컨 NNG X 2 X 5 3 10 7 4
#
# 엔 NNG X 2 X X 1 3 X 19
#
# 엘리베이터NNG 1 1 X 1 1 4 3 2
#
# 여 NNG 1 2 X 1 38 42 2 6
#
# 여관 NNG X 2 X 5 X 7 X 1
#
# 여권 NNG 6 14 X 5 7 32 X 11
#
# 여기 NNG 1 X X X 1 2 X 2
#
# 여기저기 NNG X X X 5 3 8 2 34
#
# 여동생 NNG 2 5 X 9 10 26 5 7
#
# 여드름 NNG X X X 2 11 13 X 6
#
# 여름 NNG 9 20 4 39 31 103 29 117
#
# 여자 NNG 41 36 24 18 144 263 314 1094
#
# 여학생 NNG X 2 X 1 11 14 X 14
#
# 여행 NNG 23 1 30 2 3 59 119 2
#
# 여행사 NNG 6 7 9 7 5 34 15 10
#
#
#
# - 39 -
#
# 여행자 NNG X 4 X 2 1 7 X X
#
# 여행지 NNG X 6 X 6 7 19 3 2
#
# 역 NNG 1 1 13 8 1 24 5 5
#
# 역사 NNG X 14 2 9 11 36 20 125
#
# 역사학 NNG 1 2 X 4 5 12 X X
#
# 연 NNG 3 7 X 2 1 13 17 5
#
# 연결 NNG 5 2 X 3 6 16 X 213
#
# 연고 NNG 1 X X 1 9 11 X 3
#
# 연극 NNG 6 5 X 6 5 22 11 16
#
# 연락 NNG 9 13 2 16 22 62 16 143
#
# 연락처 NNG 1 2 2 4 2 11 1 16
#
# 연세 NNG X 3 X 2 3 8 X 14
#
# 연습 NNG 19 2 4 6 108 139 8 85
#
# 연인 NNG 1 X X X 1 2 X 3
#
# 연주 NNG X 2 X X 6 8 X 11
#
# 연필 NNG 7 6 6 22 1 42 17 10
#
# 연휴 NNG 9 X X 4 1 14 1 2
#
# 열 NNG 6 1 X 9 1 17 1 1
#
# 열람실 NNG X 1 X 3 X 4 1 19
#
# 열쇠 NNG 3 3 X 2 X 8 X 24
#
# 열차 NNG 2 X X 11 2 15 2 6
#
# 엽서 NNG 4 2 X 2 5 13 1 8
#
# 엿새 NNG X 1 X X 1 2 X X
#
# 영문학 NNG X 1 X 2 1 4 X X
#
# 영상 NNG 1 2 X X 1 4 1 22
#
# 영수 NNG X X 20 19 X 39 17 X
#
# 영하 NNG 1 X X X 2 3 X 1
#
# 영향 NNG X 1 X X 2 3 X 127
#
# 영화 NNG 58 57 41 117 95 368 116 1
#
# 영화관 NNG X 7 1 2 X 10 6 15
#
# 영화배우 NNG X X X 3 4 7 1 X
#
# 옆 NNG 33 16 3 17 46 115 16 261
#
# 옆집 NNG X 1 X 1 X 2 1 7
#
# 예 NNG X X 1 X 2 3 3 8
#
# 예금 NNG X 1 1 3 X 5 2 X
#
# 예매 NNG 6 2 X 7 X 15 5 7
#
# 예보 NNG X 3 X 2 23 28 1 1
#
#
#
# - 40 -
#
# 예술 NNG 1 X X X 1 2 1 20
#
# 예식장 NNG X X X 2 8 10 X 3
#
# 예약 NNG X 14 X 16 1 31 21 40
#
# 예요 NNG X 2 X 1 4 7 X X
#
# 예절 NNG 2 X X 4 1 7 X 17
#
# 예정 NNG X 1 X 1 X 2 3 13
#
# 옛날 NNG 1 14 6 3 6 30 6 567
#
# 오늘 NNG 99 60 55 55 135 404 150 123
#
# 오래간만 NNG X X X 1 29 30 4 2
#
# 오랜만 NNG X 4 X 2 1 7 15 25
#
# 오랫동안 NNG X X X 6 4 10 2 4
#
# 오렌지 NNG X 2 2 2 1 7 4 17
#
# 오른쪽 NNG 15 12 5 10 50 92 5 110
#
# 오리 NNG X 10 1 4 X 15 3 1
#
# 오빠 NNG 1 2 X 13 14 30 X 813
#
# 오이 NNG X 3 3 1 X 7 9 5
#
# 오일 NNG 1 1 X 2 3 7 X 9
#
# 오전 NNG 12 11 X 12 28 63 36 18
#
# 오토바이 NNG X 4 X X 6 10 X X
#
# 오페라 NNG X 2 X 1 X 3 X 2
#
# 오피스텔 NNG X 2 X 3 X 5 X 2
#
# 오후 NNG 50 38 17 32 57 194 67 53
#
# 온돌 NNG X 2 X 1 X 3 X X
#
# 온천 NNG X X X 3 4 7 X 1
#
# 올림 NNG X 3 1 1 X 5 5 1
#
# 올림픽 NNG X 3 9 X 4 16 1 13
#
# 올케 NNG X 1 X 2 X 3 X X
#
# 올해 NNG 1 3 X 3 4 11 6 55
#
# 옷 NNG 2 2 19 1 137 161 64 1
#
# 옷걸이 NNG X 1 X 3 3 7 X 4
#
# 옷장 NNG 3 4 X 2 5 14 X 4
#
# 옷차림 NNG X 3 X X 12 15 X 4
#
# 와이셔츠 NNG 1 2 X 2 2 7 X 3
#
# 완성 NNG 6 X X X 5 11 X 6
#
# 왕 NNG 35 4 X 3 5 47 X 1
#
# 왕복 NNG X 3 X 1 X 4 X X
#
# 왕비 NNG X 1 X 1 X 2 X 5
#
#
#
# - 41 -
#
# 왕자 NNG X 1 X 1 X 2 X 12
#
# 외국 NNG 8 7 4 4 1 24 33 186
#
# 외국어 NNG X 9 2 2 4 17 12 52
#
# 외국인 NNG 10 3 X 8 13 34 6 X
#
# 외모 NNG X 6 X X 27 33 X 37
#
# 외삼촌 NNG 2 X X 1 X 3 X 1
#
# 외식 NNG X 5 X 2 X 7 X 2
#
# 외출 NNG 3 7 X 2 3 15 8 8
#
# 외할머니 NNG 1 1 X 3 2 7 1 4
#
# 외할아버지NNG 1 1 X 3 2 7 X 6
#
# 왼쪽 NNG 20 10 4 6 39 79 8 100
#
# 요금 NNG 9 4 X 14 4 31 14 11
#
# 요리 NNG 13 8 9 16 27 73 11 49
#
# 요일 NNG 4 15 5 17 3 44 13 101
#
# 요즘 NNG 10 35 24 32 76 177 58 243
#
# 욕실 NNG X 4 X 1 2 7 X 4
#
# 용돈 NNG 3 X X 1 3 7 X 13
#
# 용품 NNG X 1 X 3 X 4 1 3
#
# 우비 NNG X 1 X X 1 2 X 2
#
# 우산 NNG 10 8 5 6 19 48 31 22
#
# 우울 NNG 3 1 X 3 X 7 X 67
#
# 우유 NNG 7 2 2 7 30 48 16 32
#
# 우체국 NNG 30 4 22 14 75 145 41 4
#
# 우편 NNG 2 1 X 3 5 11 X 10
#
# 우편물 NNG 1 X X 2 X 3 X 3
#
# 우표 NNG 8 1 2 2 14 27 8 X
#
# 우회전 NNG 1 1 X 3 8 13 X 4
#
# 운동 NNG 26 31 16 45 67 185 120 20
#
# 운동복 NNG 1 1 X 2 3 7 3 X
#
# 운동장 NNG 9 4 1 8 11 33 11 8
#
# 운동화 NNG 19 4 X 5 5 33 7 3
#
# 운전 NNG X 11 9 17 X 37 25 90
#
# 웃음 NNG 3 1 X X X 4 X 2
#
# 원 NNG 1 1 15 42 1 60 70 1
#
# 원룸 NNG X 5 X 9 35 49 X X
#
# 원어 NNG X X 1 X 5 6 X X
#
# 원인 NNG X 2 X 2 X 4 X 27
#
#
#
# - 42 -
#
# 원피스 NNG 1 1 X 5 12 19 X 3
#
# 월급 NNG 6 2 X 1 X 9 7 39
#
# 월드컵 NNG X X X 5 5 10 X X
#
# 월세 NNG X 1 X 3 2 6 X 6
#
# 월요일 NNG 25 2 12 16 9 64 21 40
#
# 웨딩드레스NNG 1 1 1 X X 3 X 1
#
# 웨이 NNG X X X 15 2 17 X 2
#
# 웬일 NNG X X X 6 7 13 X 41
#
# 위 NNG 3 1 7 14 3 28 15 17
#
# 위치 NNG 1 4 4 5 41 55 8 3
#
# 위험 NNG X 3 X 1 2 6 1 72
#
# 윗사람 NNG X X X 1 1 2 X 4
#
# 유 NNG 1 1 2 1 2 7 9 18
#
# 유리 NNG 2 2 1 X X 5 2 27
#
# 유스호스텔NNG 1 1 X X X 2 X 4
#
# 유월 NNG 6 2 X 1 1 10 1 1
#
# 유적지 NNG X 1 X 4 3 8 X X
#
# 유채꽃 NNG X 1 X X 4 5 X 1
#
# 유학 NNG 1 3 X 5 4 13 26 38
#
# 유행 NNG X 3 X 3 17 23 2 38
#
# 육교 NNG 1 1 X 3 7 12 X 3
#
# 육일 NNG X X X 1 1 2 X X
#
# 은행 NNG 19 21 14 15 69 138 56 32
#
# 은행원 NNG X 3 X 9 4 16 X X
#
# 음 NNG 1 1 30 2 18 52 1 2
#
# 음료 NNG X 1 X 1 X 2 X 12
#
# 음료수 NNG 1 4 X 2 5 12 3 21
#
# 음성 NNG X X X 5 2 7 X 131
#
# 음식 NNG 47 44 11 124 74 300 83 114
#
# 음식점 NNG 1 1 X 3 X 5 X 16
#
# 음악 NNG 10 16 7 23 38 94 37 2
#
# 음악가 NNG X 1 X 1 X 2 1 X
#
# 음악회 NNG X 5 X 8 12 25 6 2
#
# 의견 NNG X 1 X X 5 6 X 56
#
# 의미 NNG X 1 X X 12 13 X 2
#
# 의사 NNG 6 4 4 20 1 35 7 1
#
# 의자 NNG 30 5 6 14 21 76 16 1
#
#
#
# - 43 -
#
# 의학 NNG X 2 X 3 3 8 X 1
#
# 이 NNG 7 1 1 2 2 13 2 12
#
# 이국 NNG X 1 X X 4 5 X 4
#
# 이다 NNG X X 2 X 7 9 X 1
#
# 이동 NNG 4 X X X 3 7 X 35
#
# 이름 NNG 65 31 8 45 55 204 33 371
#
# 이마 NNG X 1 1 X 1 3 X 7
#
# 이메일 NNG 11 3 X 5 33 52 3 31
#
# 이모 NNG 1 X X 3 3 7 4 28
#
# 이미지 NNG 1 X X X 7 8 X 115
#
# 이발소 NNG X 4 1 X 1 6 X X
#
# 이번 NNG 68 47 17 54 59 245 56 363
#
# 이사 NNG 2 9 10 39 28 88 43 31
#
# 이삿짐 NNG 1 2 X 3 X 6 X X
#
# 이상 NNG 6 4 X 4 19 33 8 699
#
# 이상형 NNG X 1 X X 1 2 X 4
#
# 이야기 NNG 145 21 19 1 414 600 91 301
#
# 이용 NNG 10 12 X 9 33 64 23 228
#
# 이유 NNG 4 10 1 8 18 41 X 244
#
# 이제 NNG 1 1 X 8 7 17 5 46
#
# 이틀 NNG 4 5 X 10 4 23 2 40
#
# 이팔 NNG 1 X X X 1 2 X X
#
# 이해 NNG 2 2 X 6 5 15 6 1
#
# 인 NNG 1 1 1 1 34 38 5 5
#
# 인구 NNG X 8 X 1 22 31 X 17
#
# 인기 NNG 1 8 X 4 X 13 6 4
#
# 인분 NNG 7 X 5 13 6 31 X X
#
# 인사 NNG 7 8 1 19 17 52 42 1
#
# 인사말 NNG 1 1 X X 3 5 5 6
#
# 인삼 NNG 2 6 X 2 X 10 7 8
#
# 인상 NNG X 6 X 3 10 19 X 66
#
# 인실 NNG X X X 4 3 7 X 1
#
# 인용 NNG 1 2 X X X 3 X 2
#
# 인출기 NNG X X X 3 2 5 X X
#
# 인터넷 NNG 13 X 3 6 7 29 11 227
#
# 인터뷰 NNG X X X 1 11 12 X 34
#
# 인형 NNG 2 2 X 8 X 12 X 13
#
#
#
# - 44 -
#
# 일 NNG 1 8 1 1 3 14 37 1
#
# 일과 NNG 3 X X X 5 8 X 3
#
# 일기 NNG 2 5 X 2 25 34 7 11
#
# 일반 NNG X X X 3 3 6 X 237
#
# 일상 NNG X 1 X X 1 2 X 40
#
# 일상생활 NNG X 1 X X 2 3 X 1
#
# 일시 NNG 1 X X 1 1 3 1 7
#
# 일식 NNG 1 X X 1 X 2 X 1
#
# 일식집 NNG X 2 X 3 X 5 X 2
#
# 일요일 NNG 72 12 9 10 33 136 42 48
#
# 일월 NNG 1 X X 1 2 4 X 14
#
# 일정 NNG 1 3 X 2 2 8 X 70
#
# 일주 NNG X 2 X 1 X 3 X 1
#
# 일주일 NNG 3 X X X 7 10 1 X
#
# 읽기 NNG 1 1 X 1 17 20 X 1
#
# 입 NNG 1 1 X 1 24 27 1 26
#
# 입구 NNG 3 1 X 2 4 10 1 13
#
# 입니다 NNG 1 X X 2 X 3 X X
#
# 입원 NNG X 1 X 4 X 5 4 7
#
# 입장권 NNG 1 X 5 X X 6 X X
#
# 입장료 NNG X X 4 X 2 6 6 2
#
# 입학 NNG 6 1 X 1 5 13 1 26
#
# 자 NNG 31 3 1 3 10 48 16 23
#
# 자동 NNG 1 X X 3 X 4 X 55
#
# 자동차 NNG 6 15 16 9 6 52 15 32
#
# 자랑 NNG 1 1 X X X 2 X 1
#
# 자료 NNG X X X 3 13 16 1 1
#
# 자리 NNG 11 5 2 13 2 33 12 7
#
# 자신 NNG X 12 X 1 36 49 5 2
#
# 자연 NNG X 1 X 2 5 8 X 105
#
# 자유 NNG 8 11 X 1 2 22 X 79
#
# 자장면 NNG 3 1 2 8 X 14 X X
#
# 자전거 NNG 5 6 2 16 4 33 12 24
#
# 작년 NNG 1 6 3 8 5 23 13 150
#
# 작다 NNG 2 X X X 2 4 X X
#
# 작은아버지NNG X 2 X 2 X 4 X 4
#
# 작은어머니NNG X 2 X 1 X 3 X X
#
#
#
# - 45 -
#
# 잔 NNG 5 1 7 16 18 47 9 1
#
# 잔디밭 NNG 1 X X X 1 2 X 2
#
# 잔치 NNG 3 3 X X X 6 4 2
#
# 잘못 NNG 1 1 1 X 2 5 X 68
#
# 잠 NNG 14 3 3 21 11 52 20 4
#
# 잠깐 NNG 15 11 6 11 17 60 12 8
#
# 잠시 NNG 7 2 X 1 1 11 2 17
#
# 잠옷 NNG 1 1 X 1 X 3 X 9
#
# 잡지 NNG 7 3 X 8 1 19 10 19
#
# 잡채 NNG 6 1 X 3 X 10 X 1
#
# 장 NNG 1 1 10 5 5 22 1 5
#
# 장갑 NNG 1 4 X 2 7 14 5 1
#
# 장구 NNG X 1 X X 1 2 X 1
#
# 장마 NNG 1 6 X X 2 9 X 2
#
# 장마철 NNG 2 1 X 1 1 5 1 X
#
# 장면 NNG 3 1 2 8 15 29 X 103
#
# 장미 NNG 5 2 X 1 X 8 6 3
#
# 장미꽃 NNG 15 1 X 5 1 22 1 1
#
# 장소 NNG 8 5 8 18 52 91 49 50
#
# 장점 NNG X 3 X X 1 4 X 27
#
# 재료 NNG X 9 X 2 1 12 X 13
#
# 재미 NNG 1 3 1 1 1 7 2 56
#
# 재즈 NNG X X X 4 6 10 X 3
#
# 재킷 NNG X 1 X 1 X 2 X X
#
# 저 NNG 3 1 X 2 7 13 1 1
#
# 저기 NNG 1 X X 5 1 7 2 34
#
# 저녁 NNG 61 39 30 35 64 229 74 118
#
# 저울 NNG 2 1 X 1 3 7 X 4
#
# 전 NNG 12 1 1 2 5 21 24 1
#
# 전공 NNG 1 6 5 11 27 50 17 2
#
# 전국 NNG 1 1 X 2 3 7 X 12
#
# 전기 NNG X 2 X 2 X 4 3 2
#
# 전망 NNG X 2 X 11 5 18 X 3
#
# 전세 NNG X 1 X 1 3 5 X 3
#
# 전시회 NNG X 1 X 1 3 5 X X
#
# 전자 NNG 1 1 1 3 3 9 2 7
#
# 전쟁 NNG X 1 X 3 X 4 X 130
#
#
#
# - 46 -
#
# 전철 NNG 1 X X 1 X 2 X 9
#
# 전체 NNG 1 4 X 1 6 12 X 213
#
# 전통 NNG 3 3 X 4 5 15 2 48
#
# 전화 NNG 5 90 2 133 113 343 133 1
#
# 전화기 NNG 3 X 2 1 2 8 11 28
#
# 전화번호 NNG 6 3 3 26 12 50 12 X
#
# 전화벨 NNG X 1 X 2 X 3 X 6
#
# 절 NNG 1 2 2 9 4 18 18 7
#
# 점 NNG 1 1 3 1 2 8 3 18
#
# 점수 NNG X X X 1 2 3 X 267
#
# 점심 NNG 20 15 15 37 28 115 32 55
#
# 점원 NNG 7 X X X 21 28 X 2
#
# 점퍼 NNG X 2 X 1 7 10 X X
#
# 점프 NNG X 3 3 X 1 7 X 1
#
# 접 NNG 2 1 X X 1 4 X 15
#
# 접시 NNG X 1 X 2 X 3 X 1
#
# 젓가락 NNG 3 X 1 7 2 13 1 8
#
# 정 NNG 1 2 9 10 11 33 15 91
#
# 정거장 NNG 2 X X X 11 13 X 15
#
# 정도 NNG 1 10 X 6 42 59 7 1215
#
# 정류장 NNG X X 5 9 23 37 8 11
#
# 정리 NNG X 7 3 18 23 51 1 173
#
# 정문 NNG 5 X 3 13 7 28 X 11
#
# 정보 NNG X 4 X X 14 18 2 1
#
# 정상 NNG 1 X X 1 X 2 X 41
#
# 정수기 NNG X X X 1 4 5 X 1
#
# 정신 NNG X X X 1 5 6 1 152
#
# 정원 NNG 3 4 X X X 7 X 5
#
# 정장 NNG 3 4 X 5 10 22 X 18
#
# 정치 NNG X 1 X X 3 4 X 181
#
# 정치학 NNG 1 2 X 1 X 4 X 2
#
# 제공 NNG 2 9 X X 2 13 1 37
#
# 제과점 NNG 1 X X 1 X 2 X X
#
# 제목 NNG 2 4 X 3 10 19 2 1
#
# 제안 NNG 1 1 X X 5 7 X 31
#
# 제일 NNG 12 22 6 52 10 102 14 3
#
# 제품 NNG X 1 X 2 1 4 X 139
#
#
#
# - 47 -
#
# 조 NNG 1 1 X X 2 4 X 65
#
# 조건 NNG X 2 X X 1 3 X 9
#
# 조교 NNG 1 X X X 1 2 X 62
#
# 조금 NNG 1 3 X 9 15 28 9 1
#
# 조깅 NNG X 2 X 1 5 8 X 3
#
# 조끼 NNG X 1 X 1 7 9 X 1
#
# 조사 NNG X X X 1 11 12 X 2
#
# 조식 NNG 1 3 X X X 4 X X
#
# 조심 NNG 7 1 X 10 1 19 13 59
#
# 조언 NNG X 2 X X 2 4 X 8
#
# 조카 NNG X 2 X 1 X 3 2 22
#
# 졸업 NNG 11 8 5 18 17 59 17 156
#
# 졸업식 NNG X 1 X 6 4 11 2 9
#
# 종교 NNG X 1 X 2 X 3 X 111
#
# 종류 NNG X 5 X 6 5 16 X 84
#
# 종업원 NNG 9 1 X 1 5 16 X 1
#
# 종이 NNG 4 4 X 5 2 15 1 11
#
# 종일 NNG 4 X 1 2 1 8 2 51
#
# 종착역 NNG X X X 1 1 2 X X
#
# 종합 NNG 9 X X 5 X 14 X 44
#
# 좌석 NNG X X 4 X 1 5 X 2
#
# 좌회전 NNG 1 2 X 3 5 11 X 1
#
# 주 NNG 8 1 3 12 3 27 1 6
#
# 주다 NNG 1 X X X 1 2 X X
#
# 주도 NNG 1 X X X 3 4 X 1
#
# 주말 NNG 64 45 15 53 91 268 85 69
#
# 주머니 NNG 17 6 1 7 4 35 5 2
#
# 주문 NNG 9 7 X 7 9 32 13 13
#
# 주민 NNG X 1 X 1 1 3 7 2
#
# 주방 NNG X 2 X 1 X 3 X 5
#
# 주변 NNG X 2 X 1 10 13 X 5
#
# 주부 NNG X 2 X 2 3 7 1 3
#
# 주사 NNG 1 1 X 3 1 6 X 16
#
# 주소 NNG 14 7 1 13 13 48 4 33
#
# 주스 NNG 1 6 3 9 28 47 14 6
#
# 주위 NNG 1 X X X 1 2 X 63
#
# 주의 NNG X 4 X 2 6 12 1 3
#
#
#
# - 48 -
#
# 주인 NNG 3 1 1 2 6 13 7 24
#
# 주인공 NNG X X X 4 2 6 X 44
#
# 주일 NNG 3 X 1 1 7 12 1 1
#
# 주제 NNG X 2 X X 1 3 X 169
#
# 주차 NNG X 5 X 4 X 9 1 16
#
# 주차장 NNG 1 1 X X X 2 4 4
#
# ...
#
# 차05 명사 8 8 4 19 12 51 28 A
#
# 차08 명사 8 8 4 19 12 51 28 A
#
# 차갑다 형용사 X X X X 2 2 X B
#
# 차다02 동사 4 2 2 X 5 13 4 B
#
# 차리다 동사 X 4 X 2 7 13 X B
#
# 착하다 형용사 3 1 1 1 X 6 1 B
#
# 참 부사 6 5 3 12 8 34 9 A
#
# 참기름 명사 X 1 7 2 X 10 X B
#
# 창문 명사 15 4 2 17 9 47 14 A
#
# 찾다 동사 51 34 16 29 68 198 94 A
#
# 찾아가다 동사 3 2 X 1 2 8 1 B
#
# 찾아오다 동사 1 X 2 3 10 16 X B
#
# 채소 명사 X X X 8 X 8 X B
#
# 책 명사 4 3 2 19 94 122 8 A
#
# 책상 명사 29 18 10 27 18 102 29 A
#
# 책장 명사 3 5 X X 1 9 X 없음
#
# 처음 명사 5 13 1 12 18 49 12 A
#
# 천 수사 2 1 1 2 8 14 1 A
#
# 천천히 부사 8 X X 2 4 14 22 A
#
# 철 명사 2 1 33 1 2 39 2 B
#
# 첫 관형사 11 9 3 5 X 28 4 B
#
# 첫째 관형사 1 1 X 4 X 6 X A
#
# 청바지 명사 X 5 X 2 14 21 X A
#
# 청소기 명사 X 1 X 4 X 5 2 B
#
# 청소하다 동사 11 7 13 14 24 69 54 A
#
# 초대 명사 11 12 4 25 X 52 25 A
#
#
#
# - 121 -
#
# 초등학교 명사 3 X X 3 1 7 1 A
#
# 초등학생 명사 X X X 1 1 2 2 C
#
# 초록색 명사 X 2 X 1 5 8 X B
#
# 초콜릿 명사 1 1 X 4 X 6 X A
#
# 촬영하다 동사 X 2 X 2 3 7 X B
#
# 최고 명사 3 4 X 1 12 20 X B
#
# 추다 동사 1 1 7 1 4 14 1 A
#
# 추석 명사 2 1 X 1 X 4 X C
#
# 추억 명사 1 X X 4 2 7 1 B
#
# 축구 명사 7 4 15 10 33 69 19 A
#
# 축제 명사 9 3 X X 2 14 3 B
#
# 축하하다 동사 23 4 4 9 9 49 24 B
#
# 출구 명사 2 1 X 3 11 17 5 B
#
# 출근하다 동사 1 13 1 3 3 21 7 B
#
# 출발하다 동사 5 12 7 14 5 43 26 B
#
# 출장 명사 X 9 2 4 1 16 X B
#
# 춤 명사 2 4 9 2 15 32 1 A
#
# 춤추다 동사 X X X 1 4 5 X A
#
# 춥다 형용사 22 5 13 31 59 130 17 A
#
# 취미 명사 6 5 X 21 78 110 55 A
#
# 취소하다 동사 X 3 X 7 X 10 4 B
#
# 취직하다 동사 2 10 X 16 23 51 9 B
#
# 층 명사 23 8 4 1 39 75 1 A
#
# 치과 명사 3 2 X 1 X 6 X B
#
# 치다 동사 40 12 14 24 55 145 48 A
#
# 치료하다 동사 2 2 X 6 5 15 X B
#
# 치마 명사 8 1 2 5 14 30 14 A
#
# 치약 명사 X 4 X 1 15 20 X A
#
# 친구 명사 266 139 64 247 419 1135 313 A
#
# 친절하다 형용사 11 1 14 16 4 46 4 B
#
# 친척 명사 1 1 X 2 X 4 3 B
#
# 친하다 형용사 4 2 3 7 4 20 3 B
#
# 칠 수사 2 3 5 10 2 22 9 A
#
# 칠십 수사 2 2 1 3 1 9 X A
#
# 칠월 명사 1 1 1 1 1 5 1 A
#
# 칠판 명사 7 X 1 7 3 18 X A
#
# 침대 명사 4 5 X 5 17 31 9 A
#
#
#
# - 122 -
#
# 칫솔 명사 X X X X 5 5 X A
#
# 카드 명사 18 34 X 18 16 86 7 A
#
# 카레 명사 X 1 X 9 X 10 X B
#
# 카메라 명사 X 4 2 2 3 11 4 A
#
# 카페 명사 3 1 X 1 1 6 X B
#
# 칼 명사 X 2 2 6 1 11 X A
#
# 캐나다 명사 X 3 2 6 9 20 5 A
#
# 커피 명사 19 14 6 23 55 117 33 A
#
# 커피숍 명사 5 10 4 8 48 75 17 없음
#
# 컴퓨터 명사 28 12 21 20 44 125 36 A
#
# 컵 명사 5 1 X 5 1 12 2 A
#
# 케이크 명사 1 8 1 20 2 32 10 없음
#
# 켜다 동사 5 6 X 4 2 17 4 A
#
# 코 명사 1 6 2 1 18 28 6 A
#
# 코트 명사 X 13 5 2 1 21 5 C
#
# 코피 명사 1 X X 1 3 5 X B
#
# 콜라 명사 1 6 3 3 23 36 1 A
#
# 콧물 명사 3 1 X 6 8 18 1 B
#
# 콩 명사 X X 1 2 X 3 X B
#
# 크기 명사 2 5 X X 9 16 3 B
#
# 크리스마스명사 1 5 2 15 X 23 X A
#
# 큰아버지 명사 1 3 X 3 X 7 X C
#
# 큰어머니 명사 X 3 X 1 X 4 X C
#
# 키 명사 2 11 4 15 43 75 3 A
#
# 킬로그램 명사 3 2 X X X 5 2 B
#
# 킬로미터 명사 X X X X 4 4 X B
#
# 타다 동사 6 3 4 12 137 162 2 A
#
# 탁구 명사 1 1 1 6 5 14 X C
#
# 태국 명사 1 5 X 2 18 26 X 없음
#
# 태권도 명사 7 7 3 4 1 22 26 A
#
# 태어나다 동사 X 2 X 3 X 5 3 A
#
# 태풍 명사 X 1 X X 3 4 X B
#
# 택시 명사 6 3 2 1 14 26 22 A
#
# 탤런트 명사 X X X X X 0 X B
#
# 터미널 명사 1 2 1 2 9 15 3 B
#
# 테니스 명사 17 8 21 3 26 75 14 A
#
# 테이블 명사 X 2 6 X 1 9 X A
#
#
#
# - 123 -
#
# 텔레비전 명사 16 14 14 23 36 103 18 A
#
# 토마토 명사 X X 2 3 5 10 X B
#
# 토요일 명사 21 51 11 24 54 161 52 A
#
# 통 의존명사 2 2 3 1 1 9 13 B
#
# 통장 명사 X 11 X 7 20 38 5 B
#
# 통하다 동사 X 3 X X 12 15 X B
#
# 퇴근 명사 X 1 4 1 5 11 2 B
#
# 특별히 부사 1 3 X X 2 6 4 B
#
# 특징 명사 1 5 X 1 20 27 X B
#
# 특히 부사 6 11 3 3 7 30 6 B
#
# 틀다 동사 1 1 X X X 2 X B
#
# 틀리다 동사 4 X X X 37 41 X B
#
# 티셔츠 명사 1 4 X 5 34 44 1 B
#
# 팀 명사 X X 1 1 1 3 X A
#
# 파 명사 X 8 1 2 1 12 X B
#
# 파란색 명사 1 9 1 7 23 41 11 A
#
# 파랗다 형용사 7 X X 7 1 15 X B
#
# 파티 명사 17 23 27 24 6 97 16 A
#
# 팔01 명사 2 2 1 4 2 11 8 A
#
# 팔03 수사 2 2 1 4 2 11 8 A
#
# 팔다 동사 17 18 2 8 9 54 33 A
#
# 팔십 수사 2 2 1 2 2 9 X A
#
# 팔월 명사 2 X X 2 2 6 X A
#
# 패션 명사 X 1 X 2 2 5 X B
#
# 펴다 동사 2 1 X X 1 4 X B
#
# 편09 명사 2 2 4 2 5 15 3 B
#
# 편지 명사 24 15 26 16 68 149 57 A
#
# 편하다 형용사 4 10 4 19 4 61 9 B
#
# 평일 명사 X 2 X 2 X 4 1 B
#
# 포도 명사 3 1 X 4 9 17 5 A
#
# 포장 명사 1 X X 4 6 11 2 B
#
# 표 명사 6 1 1 1 15 24 11 A
#
# 표현 명사 1 2 X X 97 100 X B
#
# 푹 부사 1 4 2 2 18 27 8 B
#
# 풀01 명사 1 1 1 X 2 5 2 B
#
# 풀다 동사 X 3 X 1 12 16 2 B
#
# 프랑스 명사 2 12 5 6 5 30 X A
#
#
#
# - 124 -
#
# 프로그램 명사 X 4 1 2 4 11 1 B
#
# 피곤하다 형용사 4 5 9 16 5 39 2 A
#
# 피다 동사 1 4 X 5 4 14 2 B
#
# 피아노 명사 X 8 4 7 5 24 22 A
#
# 피우다 동사 16 14 5 9 6 50 13 A
#
# 피자 명사 26 3 2 16 X 47 X A
#
# 필름 명사 4 5 1 X X 10 X B
#
# 필요하다 형용사 13 12 15 22 14 76 17 A
#
# 필통 명사 2 1 X 1 1 5 X B
#
# 하나 수사 8 25 7 20 25 85 22 A
#
# 하늘 명사 4 3 X 3 12 22 4 A
#
# 하늘색 명사 X 1 X 1 2 4 X 없음
#
# 하다 동사 1 4 3 2 3 13 10 A
#
# 하루 명사 11 7 1 11 42 72 19 B
#
# 하숙 명사 X 6 7 1 5 19 1 없음
#
# 하숙집 명사 24 8 45 33 24 134 19 B
#
# 하얀색 명사 X 1 1 3 6 11 X B
#
# 하얗다 형용사 3 X X 5 1 9 1 B
#
# 하지만 부사 20 X 11 7 X 38 12 A
#
# 학교 명사 3 2 8 5 151 169 6 A
#
# 학기 명사 6 1 3 4 4 18 1 B
#
# 학년 명사 X 5 X X 2 7 X A
#
# 학생 명사 1 2 1 1 79 84 1 A
#
# 학생증 명사 3 2 X 2 X 7 1 B
#
# 학원 명사 11 1 2 3 5 22 10 B
#
# 한 관형사 84 75 34 91 145 429 52 A
#
# 한강 명사 X 2 16 1 7 26 13 A
#
# 한국 명사 117 139 44 165 344 809 219 A
#
# 한국말 명사 12 32 8 44 28 124 28 A
#
# 한국어 명사 34 22 13 19 182 270 61 A
#
# 한글 명사 X X 5 2 8 15 1 A
#
# 한번 명사 7 7 2 6 3 25 14 A
#
# 한복 명사 8 4 X 10 2 24 6 A
#
# 한식 명사 8 X X 9 X 17 X C
#
# 한자 명사 X 1 X 3 X 4 X A
#
# 할머니 명사 1 1 9 3 33 47 1 A
#
# 할아버지 명사 1 1 5 3 35 45 8 A
#
#
#
# - 125 -
#
# 할인 명사 X 3 X 3 8 14 2 B
#
# 함께 부사 29 7 X 9 45 90 58 A
#
# 합격 명사 2 2 X 1 11 16 4 B
#
# 항상 부사 4 5 X 3 6 18 17 A
#
# 해 명사 1 1 5 1 15 23 2 A
#
# 해외 명사 2 2 X 2 X 6 X B
#
# 해외여행 명사 X 1 X 1 3 5 4 B
#
# 핸드폰 명사 1 2 X 8 X 11 X A
#
# 햄버거 명사 2 1 X X 1 4 X A
#
# 햇빛 명사 X 2 X 2 16 20 X B
#
# 행복 명사 2 X 3 3 13 21 7 B
#
# 행사 명사 6 7 9 7 5 34 15 B
#
# 허리 명사 1 2 1 X 8 12 X A
#
# 현금 명사 X 13 X 8 16 37 X B
#
# 현재 명사, 부사X 5 X X 3 8 X B
#
# 형 명사 2 2 X 8 16 28 12 A
#
# 형제 명사 X 2 X 1 13 16 4 B
#
# 호 의존명사 43 19 3 6 24 95 17 A
#
# 호랑이 명사 X 2 X 10 2 14 X B
#
# 호주 명사 1 12 3 9 14 39 1 A
#
# 호텔 명사 1 39 1 24 9 74 29 A
#
# 혼자 명사 8 8 10 5 9 40 17 A
#
# 홈페이지 명사 15 X X X 3 18 X B
#
# 홍차 명사 X 1 X 1 X 2 X B
#
# 화06 명사 5 1 2 3 3 14 1 A
#
# 화가 명사 X 1 X X 1 2 X B
#
# 화나다 동사 1 X X X 4 5 X B
#
# 화내다 동사 X X X X X 0 X 없음
#
# 화요일 명사 1 2 9 5 3 20 5 A
#
# 화장실 명사 1 1 5 18 26 51 12 A
#
# 화장품 명사 X 2 X 2 5 9 7 B
#
# 화장하다 명사 X 2 X 3 X 5 X C
#
# 확인하다 동사 1 4 X 8 20 33 X B
#
# 환영하다 동사 1 1 X X 1 3 1 B
#
# 환자 명사 4 1 X 8 10 23 1 A
#
# 회사04 명사 18 80 20 60 66 244 152 A
#
# 회사원 명사 1 8 3 14 36 62 5 없음
#
#
#
# - 126 -
#
# 회색 명사 1 3 X X 13 17 X B
#
# 회의 명사 X 9 X 12 3 24 19 A
#
# 횡단보도 명사 5 1 X 7 36 49 X B
#
# 후08 명사 50 5 17 32 73 177 67 A
#
# 후배 명사 X 1 X 3 X 4 X B
#
# 휴가 명사 3 1 4 9 15 32 18 B
#
# 휴대전화 명사 X X X 2 4 6 2 없음
#
# 휴일 명사 3 X X 5 X 8 2 A
#
# 휴지 명사 X X 1 3 20 24 5 A
#
# 휴지통 명사 X 2 X X X 2 4 A
#
# 흐리다 형용사 1 5 X 6 41 53 6 B
#
# 흰색 명사 X 4 X 2 10 16 5 A
#
# 힘 명사 X 5 X 2 2 9 4 A
#
# 힘들다 형용사 2 3 X 17 47 69 31 A
#
# (가) 조남호(2003) 목록과 비교
#
# 조남호(2003)에서 제시되지 않거나 C항목에 제시된 어휘 중 한국어를 학습하는 학습자
#
# 에게 필요하다고 판단한 어휘는 다음과 같다.
#
# ․조남호(2003) C항목에 포함된 어휘
#
# 국적, 귤, 그저께, 남미, 내과, 데이트, 떡국, 매주(每週), 무료, 밀리다, 복숭아, 사업가, 삼계
#
# 탕, 수도09, 수저, 시디(CD), 신청서, 양식(洋食), 연예인, 영화관, 영화배우, 와이셔츠, 외할
#
# 아버지, 월세, 일식(日食), 작은아버지, 작은어머니, 조개, 중식(中食), 초등학생, 추석, 코트,
#
# 큰아버지, 큰어머니, 탁구, 한식(韓食), 화장02
#
# ․조남호(2003)에 제시되지 않은 어휘
#
# 꽃집, 눈사람, 눈싸움, 대학원생, 드시다, 듣기, 등산화, 등산복, 로션, 말하기, 매점, 멕시코,
#
# 면도, 몽골, 문구점, 민속촌, 반바지, 배탈, 벚꽃, 베트남, 북, 브라질, 빵집, 사거리
#
# 사이다, 사이즈, 사인14, 삼거리, 샴푸, 세일, 소화제, 수영복, 수첩, 스타킹, 스페인어, 시다,
#
# 시간표, 쓰기, 씩, 아랍어, 약사, 영화표, 옷장, 외숙모, 요르단, 운동선수, 은행원, 이모부,
#
# 이집트, 인도, 일기예보, 읽기, 장마철, 재킷, 저분, 전자사전, 점퍼, 주황색, 지하철역, 짜리,
#
#
#
# - 127 -
#
# 쯤, 책장, 커피숍, 케이크, 태국, 하늘색, 하숙, 화내다, 회사원, 휴대전화
#
# 2. 표준 문법 항목 선정 및 목록
#
# 가. 표준 문법 항목 선정
#
# 이 과제의 목표는 한국어능력시험 초급 어휘 목록 개발 연구로 어휘 목록을 추출하
#
# 는 것이나, 이 과정에서 초급 단계에서 표준 문법 항목을 함께 선정하였다. 문법 형태
#
# 의 추출은 일차적으로 한국어교육용 교재와 한국어능력시험에 출현한 문법 항목을 기
#
# 준으로 삼았다. 이 자료들을 세종 형태소 분석기를 통해 문법의 범주를 나누었으나, 두
#
# 가지의 문제가 발생하였다.
#
# 첫째, 한국어교육 분야에서 문법은 국어학 범주와 달리 덩어리의 복합형태가 하나의
#
# 문법 구성 요소가 된다. ‘-고 싶다’나 ‘-지요’와 같은 형태들이 이에 속한다고 할 수 있
#
# 다. 그러나 형태소 분석기는 이를 구별하지 못하고 개개의 형태소로 모두 나누어 한국
#
# 어교육에서 유의미한 복합 형태를 추출할 수 없었다.
#
# 둘째, 이형태의 문법 요소가 각기 다른 값으로 잡히면서 문법 내용이 두 배로 늘어
#
# 난 결과가 발생하였다. 이에 문법 요소를 일차적으로 나열해 놓고, 한 문법 항목의 이
#
# 형태를 일차적으로 묶었다. 그 후 한국어교육용 교재와 한국어능력시럼에 공통적으로
#
# 출현한 문법 항목을 선별하며 난이도 검토를 시작하였다. 그 결과 총 110개의 단일 형
#
# 태소와 복합 형태를 추출할 수 있었다.
#
# 분석 결과를 표로 보이면 다음과 같다.
#
#
#
# - 128 -
#
# 형태소 분석기 결과(수정 전) 문법 항목 선별(수정 후)
#
# 연결어미 22항목 연결어미 13항목
#
# 종결어미 17항목 종결어미 22항목
#
# 선어말어미 3항목 선어말어미 3항목
#
# 조사 33항목 조사 32항목
#
# 관형형전성어미 3항목 관형형전성어미 3항목
#
# 명사형전성어미 2항목 명사형전성어미 2항목
#
# ․ ․ 부정표현 2항목
#
# ․ ․ 복합표현 33항목
#
# 총 80항목 총 110항목
#
# <표Ⅲ-1> 형태소 분석 전후 문법 항목 비교
#
# 나. 문법 항목 선정 대상 목록
#
# 형태 분석 K1 E S Y K2 합계 TOPIK 세종구어
#
# ================================================================================
#
# 거나 EC 5 24 4 11 33 77 26 X
#
# 게 EC 68 183 40 156 355 802 211 X
#
# 겠 EC 2 X X 1 5 8 X X
#
# 고 EC 432 7 97 11 1 548 4 X
#
# ㄴ가 EC X 3 X 2 6 11 1 X
#
# ㄴ다 EC 2 14 2 6 56 80 X X
#
# ㄴ다고 EC X 7 X 11 2 20 4 X
#
# ㄴ다면 EC X 5 X X 3 8 1 X
#
# ㄴ데 EC 3 18 X 22 18 61 14 X
#
# ㄴ데요 EC 3 1 X 1 X 5 X X
#
# ㄴ지 EC 3 4 X 12 54 73 2 X
#
# 나 EC 5 24 4 11 10 54 26 X
#
# 냐 EC X 4 X 1 1 6 X X
#
# 는다 EC X 1 X 1 2 4 X X
#
# 는데 EC 15 62 X 89 76 242 71 X
#
# 는데요 EC X X 1 X 1 2 11 X
#
#
#
# - 129 -
#
# 는지 EC 1 7 X 28 109 145 7 X
#
# 니까 EC 17 24 X 2 36 79 24 X
#
# 니다 EC 40 13 1 27 25 106 142 X
#
# 다 EC 2 14 2 6 1 25 142 X
#
# 다가 EC 16 3 X 2 8 29 X X
#
# 다고 EC X 7 X 11 5 23 4 X
#
# 다면 EC X 5 X X 2 7 1 X
#
# 도록 EC 1 5 X X 18 24 X X
#
# 든지 EC 2 7 X 14 18 41 6 X
#
# ㄹ까 EC X 1 X 9 17 27 5 X
#
# ㄹ까요 EC X 1 X X 3 4 29 X
#
# ㄹ지 EC 1 2 X 20 28 51 3 X
#
# 라 EC X 12 X 1 14 27 X X
#
# 라고 EC 4 31 X 37 28 100 2 X
#
# 라도 EC X 1 X X 1 2 X X
#
# 라면 EC X 5 X 1 4 10 X X
#
# 라서 EC 2 11 X 3 18 34 4 X
#
# 러 EC 22 24 28 39 19 132 98 X
#
# 려고 EC 20 37 13 61 8 139 185 X
#
# 려면 EC X 14 X 25 3 42 25 X
#
# 며 EC X 3 X 2 5 10 X X
#
# 면 EC 23 5 X 1 111 140 1 X
#
# 면서 EC X 16 X 12 14 42 27 X
#
# ㅂ니까 EC X X X 2 13 15 24 X
#
# ㅂ니다 EC 40 13 X 27 25 105 142 X
#
# ㅂ시다 EC 4 2 X 3 7 16 18 X
#
# ㅂ시오 EC X X X 8 4 12 28 X
#
# 세요 EC 17 2 2 1 3 25 48 X
#
# 습니까 EC 4 1 X 1 19 25 31 X
#
# 습니다 EC 35 3 1 23 25 87 170 X
#
# 십시오 EC X 3 X X 1 4 X X
#
# 아 EC 189 181 27 182 1695 2274 289 X
#
# 아도 EC X 10 X 18 28 56 25 X
#
# 아서 EC 102 174 17 223 275 791 215 X
#
# 아야 EC 17 46 15 85 105 268 95 X
#
# 아요 EC 45 4 22 11 47 129 274 X
#
# 야 EC 17 46 15 85 1 164 95 X
#
#
#
# - 130 -
#
# 어 EC 204 139 49 174 584 1150 233 X
#
# 어다 EC 1 4 3 2 3 13 1 X
#
# 어도 EC X 7 X 18 18 43 15 X
#
# 어서 EC 33 77 25 166 172 473 200 X
#
# 어야 EC 3 20 3 57 30 113 44 X
#
# 어요 EC 88 13 31 21 111 264 700 X
#
# 에요 EC 13 1 X 2 40 56 155 X
#
# 오 EC X 1 1 8 3 13 28 X
#
# 요 EC 3 1 1 1 4 10 11 X
#
# 으 EC 6 1 X X 94 101 X X
#
# 으니까 EC 6 6 X 30 36 78 24 X
#
# 으러 EC 1 4 11 3 19 38 18 X
#
# 으려고 EC X 2 3 11 8 24 11 X
#
# 으며 EC X 1 X 2 5 8 X X
#
# 으면 EC 6 38 X 86 111 241 59 X
#
# 으면서 EC X 9 X 3 14 26 10 X
#
# 으세요 EC 7 X X X 3 10 9 X
#
# 은데 EC 5 3 X 12 20 40 12 X
#
# 은지 EC X X X 3 8 11 1 X
#
# 을지 EC X 2 X 4 18 24 X X
#
# 읍시다 EC 1 X X 2 1 4 3 X
#
# 자고 EC X X X 11 1 12 X X
#
# 자마자 EC X 5 X X 1 6 1 X
#
# 지 EC 3 4 19 12 121 159 2 X
#
# 지만 EC 24 40 12 70 44 190 133 X
#
# 거든 EF X 1 X X 1 2 X 1
#
# 게요 EF 23 1 4 13 2 43 37 119
#
# 고요 EF 1 3 X 1 2 7 2 5
#
# 구나 EF X 1 X 8 X 9 2 529
#
# 군요 EF 5 58 X 32 X 95 6 30
#
# 까요 EF 49 73 11 106 46 285 54 3
#
# ㄴ가요 EF 1 X X 6 X 7 X 85
#
# ㄴ다 EF X 62 2 24 43 131 X 1032
#
# ㄴ데 EF X 1 X X 1 2 X 470
#
# ㄴ데요 EF 40 10 1 11 16 78 3 222
#
# 나요 EF X 1 X 14 1 16 X 1
#
# 네요 EF 9 2 X 3 75 89 19 280
#
#
#
# - 131 -
#
# 는가 EF X 2 X X 3 5 X 166
#
# 는군요 EF X 9 X 5 X 14 X 15
#
# 는다 EF X 8 X 3 11 22 X 84
#
# 는데요 EF 4 9 1 17 16 47 26 1
#
# 니 EF 1 1 1 13 X 16 X 3
#
# 니까 EF 225 203 15 252 98 793 182 37
#
# 니까요 EF X 6 X 3 1 10 1 3
#
# 니다 EF 621 665 65 943 275 2569 1534 5
#
# 다 EF 621 62 2 24 1 710 1534 3
#
# ㄹ게 EF X X X 7 11 18 X 86
#
# ㄹ게요 EF 23 1 4 13 40 81 37 119
#
# ㄹ까 EF X 3 X 16 5 24 X 454
#
# ㄹ까요 EF 49 73 11 106 116 355 54 188
#
# ㄹ래 EF X X X 3 2 5 X 72
#
# ㄹ래요 EF X X X 7 38 45 7 19
#
# 라 EF 2 2 X 1 X 5 X 1
#
# 라고요 EF 1 2 X X X 3 X 8
#
# 래요 EF 1 1 X 7 33 42 7 19
#
# 려고요 EF X 1 X X 2 3 2 X
#
# ㅂ니까 EF 225 203 15 252 106 801 182 218
#
# ㅂ니다 EF 621 665 65 943 298 2592 1534 2841
#
# ㅂ시다 EF 70 59 X 78 28 235 61 80
#
# ㅂ시오 EF 50 114 X 90 71 325 181 18
#
# 세요 EF 149 33 49 82 13 326 60 1
#
# 습니까 EF 121 175 8 182 98 584 123 160
#
# 습니다 EF 611 719 154 823 275 2582 1589 2736
#
# 아 EF X 16 1 57 1 75 X 1
#
# 아라 EF X 2 X 7 X 9 X 27
#
# 아서요 EF 1 5 2 1 5 14 3 X
#
# 아요 EF 387 115 413 335 843 2093 559 2155
#
# 야 EF X 5 X 1 43 49 X 1
#
# 어 EF X 19 X 66 99 184 3 1
#
# 어라 EF X 1 X 2 X 3 X 42
#
# 어서요 EF 1 7 X X 2 10 X 1
#
# 어요 EF 1186 485 849 1072 2658 6250 2 1
#
# 에요 EF 382 97 276 254 473 1482 337 905
#
# 예요 EF 2 X 5 2 2 11 X 43
#
#
#
# - 132 -
#
# 오 EF 50 114 13 90 15 282 181 18
#
# 요 EF 1 10 1 6 65 83 3 1
#
# 으니까요 EF X 4 X X 1 5 1 4
#
# 으세요 EF 37 16 17 23 13 106 12 1
#
# 은데 EF X X X 1 4 5 X 197
#
# 은데요 EF 4 5 X 1 6 16 10 40
#
# 을게요 EF 4 X 1 3 2 10 2 5
#
# 을까 EF X 6 X 1 X 7 X 259
#
# 을까요 EF 24 26 X 28 46 124 19 39
#
# 을래 EF X 1 X X 1 2 X 25
#
# 읍시다 EF 7 X X 6 1 14 6 4
#
# 자 EF X 2 X 27 18 47 1 452
#
# 죠 EF X 2 X 5 21 28 3 1
#
# 지 EF X 1 X 10 14 25 1 1
#
# 지요 EF 63 1 7 32 65 168 17 1
#
# 겠 EP 74 135 14 197 180 600 194 3883
#
# 시 EP 598 394 146 520 37 1695 636 4295
#
# 았 EP 496 490 329 547 673 2535 1034 1784
#
# 었 EP 304 20 139 384 509 1356 1 1
#
# 였 EP X 1 X X 1 2 X 70
#
# 으시 EP 34 25 1 32 37 129 32 341
#
# ㄴ ETM 167 481 71 355 722 1796 358 14481
#
# 는 ETM 169 5 17 304 3 498 404 3
#
# 다는 ETM X 5 X 1 4 10 2 660
#
# 던 ETM X 25 X 15 11 51 X 1
#
# ㄹ ETM 249 322 135 389 532 1627 728 9304
#
# 라는 ETM X 19 X 1 1 21 6 2
#
# 어요 ETM 2 X X X 7 9 X X
#
# 은 ETM 59 110 25 128 253 575 168 5275
#
# 을 ETM 44 86 25 97 114 366 132 2687
#
# 기 ETN 79 106 2 203 680 1070 145 4111
#
# ㅁ ETN 1 6 X 4 33 44 5 351
#
# 음 ETN X X X 8 71 79 8 93
#
# 과 JC 77 85 13 67 143 385 72 783
#
# 나 JC 7 12 1 20 76 116 10 1
#
# 랑 JC 17 X X X 1 18 1 590
#
# 와 JC 44 53 2 61 391 551 75 507
#
#
#
# - 133 -
#
# 이나 JC 3 31 X 16 76 126 8 614
#
# 이랑 JC 5 X X X 1 6 X 240
#
# 하고 JC 17 5 7 17 15 61 15 548
#
# 과 JKB 54 31 5 51 75 216 70 354
#
# 께 JKB 33 13 2 25 20 93 22 57
#
# 랑 JKB 17 1 X X 1 19 X 713
#
# 로 JKB 74 162 48 168 324 776 160 254
#
# 로서 JKB X 1 X X 1 2 X 98
#
# 만큼 JKB 1 X X 8 12 21 X 66
#
# 보다 JKB 22 36 8 33 76 175 31 788
#
# 서 JKB 7 1 3 9 1 21 9 1
#
# 에 JKB 1210 1042 597 1353 2137 6339 1957 1
#
# 에게 JKB 98 73 2 86 138 397 131 416
#
# 에게서 JKB 7 10 X 4 6 27 3 7
#
# 에서 JKB 321 311 197 374 576 1779 531 5503
#
# 와 JKB 22 29 X 28 102 181 45 292
#
# 으로 JKB 85 116 13 137 324 675 124 4812
#
# 처럼 JKB X 16 X 11 43 70 9 535
#
# 하고 JKB 65 6 21 25 52 169 30 478
#
# 한테 JKB 25 6 20 14 41 106 27 1570
#
# 한테서 JKB 10 1 1 6 1 19 6 17
#
# 가 JKC 8 11 X 11 6 36 9 1074
#
# 이 JKC 7 19 2 18 25 71 22 1379
#
# 의 JKG 189 321 23 190 729 1452 262 6104
#
# ㄹ JKO 52 23 X 60 54 189 24 2767
#
# 를 JKO 588 652 251 849 1346 3686 1160 12221
#
# 을 JKO 853 882 224 1096 2051 5106 1564 15924
#
# 고 JKQ 2 32 5 2 2 43 4 16
#
# 라 JKQ X 3 X X 2 5 1 X
#
# 라고 JKQ 1 32 5 4 5 47 4 518
#
# 하고 JKQ 1 2 X 3 2 8 11 5
#
# 가 JKS 494 404 273 631 990 2792 633 19930
#
# 께서 JKS 25 7 1 33 33 99 18 145
#
# 서 JKS 25 7 1 33 4 70 18 145
#
# 이 JKS 474 688 274 911 1502 3849 1091 18025
#
# 아 JKV X 2 X 6 12 20 1 191
#
# 야 JKV X 4 X 9 11 24 1 88
#
#
#
# - 134 -
#
# 요 JKV 2 X 2 1 3 8 X X
#
# 까 JX 3 2 X 2 24 31 X X
#
# 까지 JX 32 49 28 88 80 277 84 1653
#
# ㄴ JX 9 15 6 23 68 121 15 4752
#
# 나 JX X 3 2 10 4 19 7 274
#
# 는 JX 768 662 275 757 974 3436 1360 14234
#
# 다 JX 2 2 5 1 20 30 20 161
#
# 대로 JX X 1 X X 4 5 X 16
#
# 도 JX 128 244 62 265 306 1005 288 2
#
# 마다 JX 14 10 5 24 20 73 20 222
#
# 만 JX 59 45 11 55 85 255 31 2559
#
# 밖에 JX 1 2 X 7 10 20 5 505
#
# 부터 JX 15 48 11 51 47 172 61 2
#
# 야 JX X 1 X 3 2 6 1 92
#
# 요 JX 16 20 20 11 45 112 20 1
#
# 은 JX 463 451 70 486 710 2180 704 15
#
# 이나 JX X 10 1 15 4 30 8 140
#
# 이란 JX X 2 X X 2 4 X 20
#
#
#
# - 135 -
#
# 다. 표준 문법 항목 선정 목록
#
# <표Ⅲ-2> 선정된 문법 항목
#
# 문법 범주 항목
#
# 연결어미
#
# (13항목)
#
# -고, -지만, -아/어서/여서(계기), -아/어서/여서(이유), -(으)니까,
#
# -(으)ㄴ데, -거나, -는데, -(으)러, -(으)려고, -(으)면서, -(으)면, -게,
#
# 종결어미
#
# (22항목)
#
# -ㅂ/습니까, -ㅂ/습니다, -아/어요(평서형), -아/어요(의문형), -아/
#
# 어요(청유형), -(이)지요?, -지요, -(으)ㄹ까요, -(으)ㄹ래요, -(으)ㅂ시
#
# 다, -(으)세요, -(으)십시오, -(으)ㄹ게요, -아/어서요, -(으)니까요, -
#
# (으)ㄴ데(요), -(이)ㄴ데요, -고요, -(으)려고요, -군요, -네요, -는군
#
# 요,
#
# 복합표현
#
# (33항목)
#
# 이/가 아니다, -고 있다, -고 싶다, -지 않다, -지 못하다, -지 말
#
# 다, -(으)ㄹ 것이다, -(으)ㄴ 것 같다, -는 것 같다, -(으)ㄹ 것 같다,
#
# -(으)ㄴ 후에, -(으)ㄹ 때, -기 전에, -기 때문에, -(으)ㄴ 지, -(으)러
#
# 가다, -(으)러 오다, -(으)려고 하다, -(으)ㄹ 수 있다, -(으)ㄹ 수 없
#
# 다, -아/어/여도 되다, -아/어/여야 되다, -아/어/여야 하다, -아/
#
# 어/여 보다, -아/어/여 주다, -기로 하다, -는 게 좋겠다, -았/었/
#
# 였으면 좋겠다, -(으)ㄴ 적이 있다, -(으)ㄴ 적이 없다, -(으)ㄹ까
#
# 봐, -(으)ㄹ까 하다, -게 되다
#
# 선어말 어미
#
# (3항목)
# -았/었/였-, -겠-, -(으)시-
#
# 조사
#
# (32항목)
#
# 부사격조사
# 에(장소), 에(시간), 에서, 서, 에게, 한테, 께, 하고, (이)랑, 와/과,
#
# 으로, 에게서, 한테서, 보다, 처럼
#
# 보조사 까지, 도, 마다, 만, 밖에, 부터, 은/는, 이나
#
# 접속조사 하고, 와/과, (이)랑, (이)나
#
# 주격조사 이/가, 께서
#
# 목적격조사 을/를
#
# 관형격조사 의
#
# 보격조사 이/가
#
# 관형형 어미
# (3항목)
#
# -(은)ㄴ, -는, -(으)ㄹ
#
# 명사형 어미
# (2항목)
#
# -음/ㅁ, -기
#
# 부정 부사
# (2항목)
#
# 안, 못
#
#
#
# - 136 -
#
# 참 고 문 헌
#
# 김정숙, 이동은, 이유경, 최은지(2007). 한국어 표준 말하기 시험 측정 도구를 위한 기
#
# 초 연구: 모의 인터뷰 평가와 학습자 담화 분석을 중심으로. 한민족어문학, 51, 한민족
#
# 어문학회, 229-256.
#
# 김정숙(2004). 한국어능력시험의 개선 방안 연구 (Ⅰ). 한국어교육 16-1. 국제한국어교
#
# 육학회.
#
# 김정숙(2005). 한국어능력시험의 개선 방안 연구 (Ⅱ). 한국어교육 16-2. 국제한국어교육
#
# 학회.
#
# 김중섭 외(2007). 한국어능력시험 문제은행 구축을 위한 표준문항개발 연구. 한국교육
#
# 과정평가원.
#
# 김홍규, 강범모(2000). 한국어 형태소 및 어휘 사용 빈도의 분석1. 고려대학교 민족문화
#
# 연구원
#
# 김홍규, 강범모(2004). 한국어 형태소 및 어휘 사용 빈도의 분석2. 고려대학교 민족문화
#
# 연구원
#
# 서상규 외(1998). 한국어 교육을 위한 기초 어휘. 서울: 문화관광부 한국어 세계화 추진
#
# 위원회.
#
# 안의정(2008). 말뭉치를 이용한 어휘의 구어성 측정과 활용. 어문논집, 57, 민족어문학
#
# 회, 93-119.
#
# 오미정(2004). 한국어 교육용 어휘 교재 개발 연구. 한국어교육, 15(3), 국제한국어교육
#
# 학회, 147-169.
#
# 이정희(2007). 한국어 외래어 교육 목록 선정에 관한 연구. 한국어교육, 18(3), 국제한국
#
# 어교육학회, 195-220.
#
# 이해영 외(2006). TOPIK 문항유형 개발을 위한 기초연구. 한국교육과정평가원.
#
# 조남호(2003). 한국어 학습용 어휘 선정 결과 보고서. 국립국어연구원 연구보고
#
# 2003-1-4.
#
# 조현용(2000) 한국어 어휘 교육 연구. 서울: 박이정.
#
# 한영균(2007). 한국어 어휘 교육과 어휘 통계 정보. 한국어교육, 18(3), 국제한국어교육
#
# 학회, 249-272.
