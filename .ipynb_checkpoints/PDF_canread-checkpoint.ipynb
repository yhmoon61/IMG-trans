# %%
#-*- encoding:utf-8
from tika import parser

PDFfileName = input()
# Out:
# 60TOPIK.pdf

# %%
print("텍스트 파일은 다음 폴더에 저장됩니다.")

print("D:\data_han")
inputpath = PDFfileName
parsed = parser.from_file(PDFfileName)
content=parsed['content']
print(content.strip())
#print(parsed["content"])
fileOut = open('fileOut.txt', 'w', encoding='utf-8')



print(parsed['content'], file=fileOut)
fileOut.close()
# Out:
# 텍스트 파일은 다음 폴더에 저장됩니다.
# D:\data_han
# 2020-09-15 19:16:38,539 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2020-09-15 19:16:43,575 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_01.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_02.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_03.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_04.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_05.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_06.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_07.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_08.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_09.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_10.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_11.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_12.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_13.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_14.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_15.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_16.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_17.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_18.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_19.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_20.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_21.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_22.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_23.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_24.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_25.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_26.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_27.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_28.pdf
# 	60회_문제지_TOPIK1_듣기, 읽기(B-홀수형).pdf_page_29.pdf
